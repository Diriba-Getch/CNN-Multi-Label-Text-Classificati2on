# %% [markdown]
# <a href="https://colab.research.google.com/github/Diriba-Getch/CNN-Multi-Label-Text-Classificati2on/blob/master/AONTC_datset_Colab_MAY27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Drive already mounted at /content/grive; to attempt to forcibly remount, call drive.mount("/content/grive", force_remount=True).

# %%
mydata = pd.read_csv('/content/grive/MyDrive/Multi Label Dataset updated.csv',encoding=("ISO-8859-1"),low_memory=False)

# %%
mydata.head()
# Out:
#    Barnoota  Teekiinolojii  Baala  ...  Unnamed: 24  Unnamed: 25  Unnamed: 26
# 0         1              0      0  ...          NaN          NaN          NaN
# 1         1              1      0  ...          NaN          NaN          NaN
# 2         1              0      0  ...          NaN          NaN          NaN
# 3         1              0      0  ...          NaN          NaN          NaN
# 4         1              0      0  ...          NaN          NaN          NaN
#
# [5 rows x 27 columns]

# %%
mydata["comment_lower"] = mydata['Contents'].str.lower()
mydata
# Out:
#       Barnoota  ...                                      comment_lower
# 0            1  ...  yuunvaarsittiin baahir dar afaan oromootiin ba...
# 1            1  ...  cehumsa teeknooloojii milkeessuu fi guddina bi...
# 2            1  ...  yuunivaarsitti amboo kampaasii walisootti, gam...
# 3            1  ...  aadaa dubbisuu uummata  keessatti dagaagsuun, ...
# 4            1  ...  bulchiinsi magaalaa adaamaa dargaggoota yuuniv...
# ...        ...  ...                                                ...
# 6346         0  ...   kiladdaa bilisummaa oromooota 8 kan hirmaachi...
# 6347         0  ...  shaampiyoonaan atleetiksii kiladdaa bilisummaa...
# 6348         0  ...  \n\nispoortii bishaan daakuu ityoophiyaa keess...
# 6349         0  ...  waldaan atileetiksii oromiyaa mataduree lammii...
# 6350         0  ...  pirezidaantiin kooriyaa kaabaa kiim joong uun,...
#
# [6351 rows x 28 columns]

# %%
import nltk
from nltk import sent_tokenize, word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
mydata['tokenized'] = mydata.apply(lambda row: nltk.word_tokenize(row['comment_lower']), axis=1)
mydata
# Out:
#       Barnoota  ...                                          tokenized
# 0            1  ...  [yuunvaarsittiin, baahir, dar, afaan, oromooti...
# 1            1  ...  [cehumsa, teeknooloojii, milkeessuu, fi, guddi...
# 2            1  ...  [yuunivaarsitti, amboo, kampaasii, walisootti,...
# 3            1  ...  [aadaa, dubbisuu, uummata, keessatti, dagaagsu...
# 4            1  ...  [bulchiinsi, magaalaa, adaamaa, dargaggoota, y...
# ...        ...  ...                                                ...
# 6346         0  ...  [kiladdaa, bilisummaa, oromooota, 8, kan, hirm...
# 6347         0  ...  [shaampiyoonaan, atleetiksii, kiladdaa, bilisu...
# 6348         0  ...  [ispoortii, bishaan, daakuu, ityoophiyaa, kees...
# 6349         0  ...  [waldaan, atileetiksii, oromiyaa, mataduree, l...
# 6350         0  ...  [pirezidaantiin, kooriyaa, kaabaa, kiim, joong...
#
# [6351 rows x 29 columns]

# %%
#to remove emoji
cleaned_data=mydata.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

# %%
cleaned_data
# Out:
#      Barnoota  ...                                          tokenized
# 0           1  ...  ['yuunvaarsittiin', 'baahir', 'dar', 'afaan', ...
# 1           1  ...  ['cehumsa', 'teeknooloojii', 'milkeessuu', 'fi...
# 2           1  ...  ['yuunivaarsitti', 'amboo', 'kampaasii', 'wali...
# 3           1  ...  ['aadaa', 'dubbisuu', 'uummata', 'keessatti', ...
# 4           1  ...  ['bulchiinsi', 'magaalaa', 'adaamaa', 'dargagg...
# ...       ...  ...                                                ...
# 6346        0  ...  ['kiladdaa', 'bilisummaa', 'oromooota', '8', '...
# 6347        0  ...  ['shaampiyoonaan', 'atleetiksii', 'kiladdaa', ...
# 6348        0  ...  ['ispoortii', 'bishaan', 'daakuu', 'ityoophiya...
# 6349        0  ...  ['waldaan', 'atileetiksii', 'oromiyaa', 'matad...
# 6350        0  ...  ['pirezidaantiin', 'kooriyaa', 'kaabaa', 'kiim...
#
# [6351 rows x 29 columns]

# %%
dataset=cleaned_data['tokenized']

# %%
dataset = dataset.str.strip()
#dataset['whitespace_removed'] = dataset['tokenized'].str.strip()

# %%
dataset
# Out:
# 0       ['yuunvaarsittiin', 'baahir', 'dar', 'afaan', ...
# 1       ['cehumsa', 'teeknooloojii', 'milkeessuu', 'fi...
# 2       ['yuunivaarsitti', 'amboo', 'kampaasii', 'wali...
# 3       ['aadaa', 'dubbisuu', 'uummata', 'keessatti', ...
# 4       ['bulchiinsi', 'magaalaa', 'adaamaa', 'dargagg...
#                               ...
# 6346    ['kiladdaa', 'bilisummaa', 'oromooota', '8', '...
# 6347    ['shaampiyoonaan', 'atleetiksii', 'kiladdaa', ...
# 6348    ['ispoortii', 'bishaan', 'daakuu', 'ityoophiya...
# 6349    ['waldaan', 'atileetiksii', 'oromiyaa', 'matad...
# 6350    ['pirezidaantiin', 'kooriyaa', 'kaabaa', 'kiim...
# Name: tokenized, Length: 6351, dtype: object

# %%
#to remove white space from the string
def remove_whitespace(dataset):
    """
    Helper function to remove any blank space from a string
   
    """
    try:
        # Remove spaces inside of the string
        x = "".join(dataset.split())

    except:
        pass
    return dataset

dataset= dataset.apply(remove_whitespace)

# %%
dataset
# Out:
# 0       ['yuunvaarsittiin', 'baahir', 'dar', 'afaan', ...
# 1       ['cehumsa', 'teeknooloojii', 'milkeessuu', 'fi...
# 2       ['yuunivaarsitti', 'amboo', 'kampaasii', 'wali...
# 3       ['aadaa', 'dubbisuu', 'uummata', 'keessatti', ...
# 4       ['bulchiinsi', 'magaalaa', 'adaamaa', 'dargagg...
#                               ...
# 6346    ['kiladdaa', 'bilisummaa', 'oromooota', '8', '...
# 6347    ['shaampiyoonaan', 'atleetiksii', 'kiladdaa', ...
# 6348    ['ispoortii', 'bishaan', 'daakuu', 'ityoophiya...
# 6349    ['waldaan', 'atileetiksii', 'oromiyaa', 'matad...
# 6350    ['pirezidaantiin', 'kooriyaa', 'kaabaa', 'kiim...
# Name: tokenized, Length: 6351, dtype: object

# %%
 dataset  = cleaned_data['tokenized']

# %%
df_1['labels'].value_counts().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9b475ea83ac5> in <module>()
# ----> 1 df_1['labels'].value_counts().plot(kind='bar')
#
# NameError: name 'df_1' is not defined

# %%
# url that extend stopwors = https://towardsdatascience.com/text-pre-processing-stop-words-removal-using-different-libraries-f20bac19929a

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sw_nltk.extend(['abbaan',
 'adda ',
 'addunyaa ',
 'adeemsifame ',
 'akka ',
 'akkan ',
 'akkas ',
 'akkasuma  ',
 'akkuma ',
 'al ',
 'alaa ',
 'amma ',
 'ammas ',
 'ammoo ',
 'an ',
 'an ',
 'ana ',
 'anaa ',
 'anaaf ',
 'anaafi ',
 'ani ',
 'argaman ',
 'armaan ',
 'arra ',
 'ati',
 'baatii ',
 'babalisuuf ',
 'bahaa  ',
 'bakka ',
 'bakkan ',
 'bakkee',
 'balleese',
 'bar ',
 'bara',
 'bar-kume',
 'barkume',
 'beeksifte',
 'beeksisaan',
 'beeksisan',
 'beeksise',
 'biiliyoona',
 'bira',
 'biratti ',
 'biyya',
 'biyyaa',
 'biyyaaleessaa ',
 'booda',
 'boodatti ',
 'bor',
 'boru',
 'boruu',
 'buuraa ',
 'carraa ',
 'dandau',
 'dha',
 'dhaabuu',
 'dhufan',
 'dhufeenyaa',
 'dhufu',
 'dhufuu',
 'dubbataniiru',
 'dura',
 'duraan',
 'dursee',
 'duula',
 'ebla ',
 'eblaa',
 'egaa',
 'eegalame ',
 'eegalamee',
 'egalame ',
 'ejansii ',
 'erga',
 'ergamaa',
 'ergamerraa ',
 'farra',
 'federaalaa',
 'fi',
 'fufa',
 'fuula ',
 'fuuldura',
 'gabaafame',
 'gad ',
 'gadi',
 'gahe ',
 'gama ',
 'gara',
 'garaagar ',
 'gargaarsa',
 'garuu',
 'giddu',
 'gidduutti ',
 'guddaa',
 'guddina ',
 'guyyaa ',
 'haa ',
 'haala',
 'haalli ',
 'hal',
 'hanga ',
 'hara',
 'hawaasa',
 'heddu',
 'hedduu ',
 'hedduun',
 'hi',
 'hime',
 'hin ',
 'hirmaana',
 'hojii ',
 'hubachiise',
 'ibsame ',
 'ibsan ',
 'idil',
 'immoo',
 'inni',
 'iraa',
 'irraa',
 'irraaf',
 'irran',
 'irratii',
 'isa',
 'isaa',
 'isaaf',
 'isaan',
 'isaani',
 'isaanii',
 'isaanis',
 'isaati',
 'isaatiin',
 'isaatu',
 'ishee',
 'isheen',
 'isheetii',
 'itiyoopiyaa',
 'itti',
 'itti',
 'ittiin',
 'ittinuu',
 'ittisuuf',
 'ittuu',
 'jala',
 'jalqaba',
 'jalqabama',
 'jalqabde',
 'jalqabamee',
 'jedhame',
 'jedhan',
 'jioota',
 'jiran',
 'kaabaa',
 'kaabaarratti',
 'kabajame',
 'kaleessa',
 'kam',
 'kan',
 'kanaaf',
 'kanaafuu',
 'kanaan',
 'kanan',
 'kanarrati',
 'kee',
 'keenya',
 'keenyaa',
 'keessaa',
 'keessaatii',
 'keessatti',
 'kenne',
 'kennu',
 'kibbaatti',
 'kiyya',
 'kiyyaan',
 'kkf',
 'koo',
 'kootiin',
 'koottu',
 'kudhan',
 'kuma',
 'kumee',
 'kun',
 'kunneen',
 'kuntalaa',
 'kurnan',
 'kutaa',
 'lafa',
 'lafaa',
 'lafaa',
 'laga',
 'lakkoofsa',
 'lakkoofsi',
 'lama',
 'lamaa',
 'lamaan',
 'lamaffaa',
 'lixaatti',
 'maal',
 'malee',
 'mana',
 'manneen',
 'manni',
 'marti',
 'miti',
 'mitii',
 'mormii',
 'muraasa',
 'murtesse',
 'na',
 'naaf',
 'naan',
 'nan',
 'ni',
 'obboo',
 'odoo',
 'oduu',
 'of ',
 'ol',
 'olaanaa',
 'olaanaan',
 'oliin',
 'olitti',
 'oota',
 'osoo',
 'osoon',
 'qaba',
 'qaban',
 'qabdu',
 'qabne',
 'qofa',
 'qophiin',
 'rratti',
 'sababa',
 'sadaasa',
 'sadaffaa',
 'sadan',
 'sadarkaa',
 'saddeet',
 'sadeen',
 'sadii',
 'sagantaa',
 'san',
 'sana',
 'sanatti',
 'sanii',
 'shan',
 'shanan',
 'shawaa',
 'si',
 'soddoma',
 'sun',
 'taasifamuu',
 'taasisee',
 'taayitaa',
 'tae',
 'tajaajila',
 'tamsasuu',
 'tasiisama',
 'tattafiin',
 'tau',
 'teenya',
 'teenyatti',
 'tii',
 'tiin',
 'tokkicha',
 'tokko',
 'tokkoffa',
 'tokkoo',
 'tooatame',
 'tumsi',
 'tumsuu',
 'turan',
 'ture',
 'waa',
 'waaraa',
 'waaraafi',
 'wagaa',
 'waggaa',
 'waggota',
 'wajjiin',
 'wal',
 'waliin',
 'walitti',
 'wanta',
 'wantoota',
 'warra',
 'xumurame',
 'yaa',
 'yommuu',
 'yeroo',
 'ykn',
 'yoo',
 'yoon','akka'])
print(len(sw_nltk))
# Out:
# 1376

# %%
sw_nltk.remove('garuu')

# %%
#create your custom stop words list
my_stop_words = ['abbaan',
 'adda',
 'addunyaa',
 'adeemsifame',
 'akka',
 'akkan',
 'akkas',
 'akkasuma',
 'akkuma',
 'al',
 'alaa',
 'amma',
 'ammas',
 'ammoo ',
 'an',
 'an',
 'ana',
 'anaa',
 'anaaf',
 'anaafi',
 'ani',
 'argaman',
 'armaan',
 'arra',
 'ati',
 'baatii',
 'babalisuuf',
 'bahaa',
 'bakka',
 'bakkan',
 'bakkee',
 'balleese',
 'bar',
 'bara',
 'bar-kume',
 'barkume',
 'beeksifte',
 'beeksisaan',
 'beeksisan',
 'beeksise',
 'biiliyoona',
 'bira',
 'biratti ',
 'biyya',
 'biyyaa',
 'biyyaaleessaa',
 'booda',
 'boodatti ',
 'bor',
 'boru',
 'boruu',
 'buuraa ',
 'carraa ',
 'dandau',
 'dha',
 'dhaabuu',
 'dhufan',
 'dhufeenyaa',
 'dhufu',
 'dhufuu',
 'dubbataniiru',
 'dura',
 'duraan',
 'dursee',
 'duula',
 'ebla ',
 'eblaa',
 'egaa',
 'eegalame ',
 'eegalamee',
 'egalame ',
 'ejansii ',
 'erga',
 'ergamaa',
 'ergamerraa ',
 'farra',
 'federaalaa',
 'fi',
 'fufa',
 'fuula ',
 'fuuldura',
 'gabaafame',
 'gad ',
 'gadi',
 'gahe ',
 'gama ',
 'gara',
 'garaagar ',
 'gargaarsa',
 'garuu',
 'giddu',
 'gidduutti',
 'guddaa',
 'guddina',
 'guyyaa ',
 'haa',
 'haala',
 'haalli',
 'hal',
 'hanga ',
 'hara',
 'hawaasa',
 'heddu',
 'hedduu',
 'hedduun',
 'hi',
 'hime',
 'hin',
 'hirmaana',
 'hojii',
 'hubachiise',
 'ibsame',
 'ibsan',
 'idil',
 'immoo',
 'inni',
 'iraa',
 'irraa',
 'irraaf',
 'irran',
 'irratii',
 'isa',
 'isaa',
 'isaaf',
 'isaan',
 'isaani',
 'isaanii',
 'isaanis',
 'isaati',
 'isaatiin',
 'isaatu',
 'ishee',
 'isheen',
 'isheetii',
 'itiyoopiyaa',
 'itti',
 'itti',
 'ittiin',
 'ittinuu',
 'ittisuuf',
 'ittuu',
 'jala',
 'jalqaba',
 'jalqabama',
 'jalqabde',
 'jalqabamee',
 'jedhame',
 'jedhan',
 'jioota',
 'jiran',
 'kaabaa',
 'kaabaarratti',
 'kabajame',
 'kaleessa',
 'kam',
 'kan',
 'kanaaf',
 'kanaafuu',
 'kanaan',
 'kanan',
 'kanarrati',
 'kee',
 'keenya',
 'keenyaa',
 'keessaa',
 'keessaatii',
 'keessatti',
 'kenne',
 'kennu',
 'kibbaatti',
 'kiyya',
 'kiyyaan',
 'kkf',
 'koo',
 'kootiin',
 'koottu',
 'kudhan',
 'kuma',
 'kumee',
 'kun',
 'kunneen',
 'kuntalaa',
 'kurnan',
 'kutaa',
 'lafa',
 'lafaa',
 'lafaa',
 'laga',
 'lakkoofsa',
 'lakkoofsi',
 'lama',
 'lamaa',
 'lamaan',
 'lamaffaa',
 'lixaatti',
 'maal',
 'malee',
 'mana',
 'manneen',
 'manni',
 'marti',
 'miti',
 'mitii',
 'mormii',
 'muraasa',
 'murtesse',
 'na',
 'naaf',
 'naan',
 'nan',
 'ni',
 'obboo',
 'odoo',
 'oduu',
 'of ',
 'ol',
 'olaanaa',
 'olaanaan',
 'oliin',
 'olitti',
 'oota',
 'osoo',
 'osoon',
 'qaba',
 'qaban',
 'qabdu',
 'qabne',
 'qofa',
 'qophiin',
 'rratti',
 'sababa',
 'sadaasa',
 'sadaffaa',
 'sadan',
 'sadarkaa',
 'saddeet',
 'sadeen',
 'sadii',
 'sagantaa',
 'san',
 'sana',
 'sanatti',
 'sanii',
 'shan',
 'shanan',
 'shawaa',
 'si',
 'soddoma',
 'sun',
 'taasifamuu',
 'taasisee',
 'taayitaa',
 'tae',
 'tajaajila',
 'tamsasuu',
 'tasiisama',
 'tattafiin',
 'tau',
 'teenya',
 'teenyatti',
 'tii',
 'tiin',
 'tokkicha',
 'tokko',
 'tokkoffa',
 'tokkoo',
 'tooatame',
 'tumsi',
 'tumsuu',
 'turan',
 'ture',
 'waa',
 'waaraa',
 'waaraafi',
 'wagaa',
 'waggaa',
 'waggota',
 'wajjiin',
 'wal',
 'waliin',
 'walitti',
 'wanta',
 'wantoota',
 'warra',
 'xumurame',
 'yaa',
 'yommuu',
 'yeroo',
 'ykn',
 'yoo',
 'yoon']

words = [word for word in text.split() if word.lower() not in my_stop_words]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
text = "Ijaarsi geengoo miira dorgoomii nutti hooreraa jedhan baratoonni mana barumsaa magaalaa Adaamaa. Waajjirri barnoota magaalichaas milkaa'ina baratootaaf hojjechaan jira jedhe. Barattoonni Kolleejjii Poolii Teeknikaa Fiiche, leenjiin Ogummaa nuuf kennamaa jiru, dandeetti kalaqaa akka gabbifannuuf nu gargaaraa jira jedhan. Leenjii  kennamu teeknolojiin  deggaruun akka hojjatus Kolleejjichi beeksiseera. Kolleejii  Barnoota barsiisota Asallaatti, baratoonni ogummaa labraatorii  barachaa jiran  ogummaa gochaan barataa jiraniin  hojiitti yeroo galan dhaloota beekumsaan qarame uumuuf  kan hojjatan ta'uu  himaniiru. Hanqina  Ogeeyyii Laabraatorii  manneen barnoota  Oromiyaa keessa  jiru furuuf hojjachaa jiraachuu    Kolleejiin  barnoota barsiisota Asallaa  beeksise. Magaalaa Asallaatti,Barattooni  mana barumsaa Cilaaloo sadarkaa 2ffaa fi   Dooshaa sadarkaa tokkoffaa, qormaata seemisteera 1ffaaf qopha'aa jirra jedhan. Geengoo qulqullina barnootaa sirnaan hojiirra oolchuun Qabxii baratootaa foyyessuuf  deeggarsa gochaa jiraachuu waajjirri barnootaa  magaalichaa beeksise."
# Out:
# Ijaarsi geengoo miira dorgoomii nutti hooreraa baratoonni barumsaa magaalaa Adaamaa. Waajjirri barnoota magaalichaas milkaa'ina baratootaaf hojjechaan jira jedhe. Barattoonni Kolleejjii Poolii Teeknikaa Fiiche, leenjiin Ogummaa nuuf kennamaa jiru, dandeetti kalaqaa gabbifannuuf nu gargaaraa jira jedhan. Leenjii kennamu teeknolojiin deggaruun hojjatus Kolleejjichi beeksiseera. Kolleejii Barnoota barsiisota Asallaatti, baratoonni ogummaa labraatorii barachaa ogummaa gochaan barataa jiraniin hojiitti galan dhaloota beekumsaan qarame uumuuf hojjatan ta'uu himaniiru. Hanqina Ogeeyyii Laabraatorii barnoota Oromiyaa keessa jiru furuuf hojjachaa jiraachuu Kolleejiin barnoota barsiisota Asallaa beeksise. Magaalaa Asallaatti,Barattooni barumsaa Cilaaloo 2ffaa Dooshaa tokkoffaa, qormaata seemisteera 1ffaaf qopha'aa jirra jedhan. Geengoo qulqullina barnootaa sirnaan hojiirra oolchuun Qabxii baratootaa foyyessuuf deeggarsa gochaa jiraachuu waajjirri barnootaa magaalichaa beeksise.
# ...

# %%
Astopwords = pd.read_csv('/content/grive/MyDrive/AONTC stopwords.csv',encoding=("ISO-8859-1"),low_memory=False)

# %%
Astopwords.head()

# %%
def remove_Astopwords(text_tokenized):
    text_clean = [word for word in text_tokenized if word not in Astopwords]
    return  text_clean
mydata['non stpwords contents'] = mydata['tokenized'].apply(lambda x: remove_Astopwords(x))
mydata.head()

# %%
#Remover stopwords, criando dicionário de stopwords
def removeAstopwords (dataset):
    Astopwords = pd.read_csv('AONTC stopwords.csv')
    list_cleaned = set(dataset)-set(Astopwords)
    return list_cleaned
dataset  = removeAstopwords( dataset)

# %%
#Remover stopwords, criando dicionário de stopwords
def removeStopWords (dataset):
    my_stopwords = pd.read_csv('stp words.csv')
    list_cleaned = set(dataset)-set(my_stopwords)
    return list_cleaned
dataset  = removeStopWords( dataset)

# %%
import nltk

# %%
stopwords = nltk.corpus.stopwords.words('oromoo')
stopwords

# %%
def remove_stopwords(text_tokenized):
    text_clean = [word for word in text_tokenized if word not in stopwords]
    return  text_clean
mydata['non stpwords contents'] = mydata['tokenized'].apply(lambda x: remove_stopwords(x))
mydata.head()

# %% [markdown]
# # CONVERT WORDS IN TO VECTORS

# %%
#Python program to generate word vectors using Word2Vec 
  
# importing all necessary modules 
from nltk.tokenize import sent_tokenize, word_tokenize 
import warnings 
  
warnings.filterwarnings(action = 'ignore')

# %%
import  gensim
from gensim import models
from gensim.models import word2vec

# %%
newsContents = mydata["Contents"].values
newsContents

# %%
newsvec = [nltk.word_tokenize(Contents)for Contents in newsContents]

# %%
newsvec

# %%
model=word2vec(newsvec,min_count=1,size=32)

# %%
model.most_similar('nama')

# %%
#?sample = open("\Users\Jesus at all\dataset\AONTC stopwords.txt", "r", encoding=("ISO-8859-1"),low_memory=False) 
#s = sample.read()

# %%
EMBEDDING_DIM=300
model = models.gensim.word2vec(sentences=newsContents,size=EMBEDDING_DIM,window=10,min_count=2,workers=4,sg=0)
words=list(model.wv.vocab)
