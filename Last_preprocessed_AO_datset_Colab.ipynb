# %% [markdown]
# <a href="https://colab.research.google.com/github/Diriba-Getch/CNN-Multi-Label-Text-Classificati2on/blob/master/Last_preprocessed_AO_datset_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Drive already mounted at /content/grive; to attempt to forcibly remount, call drive.mount("/content/grive", force_remount=True).

# %%
mydata = pd.read_csv('/content/grive/MyDrive/AOMLTC dataset.csv')

# %%
mydata.head()
# Out:
#    Education  Technology  Accident  ...  Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0        1.0           0         0  ...          NaN          NaN          NaN
# 1        1.0           0         0  ...          NaN          NaN          NaN
# 2        1.0           0         0  ...          NaN          NaN          NaN
# 3        1.0           0         0  ...          NaN          NaN          NaN
# 4        1.0           0         0  ...          NaN          NaN          NaN
#
# [5 rows x 21 columns]

# %%
mydata["comment_lower"] = mydata['Contents'].str.lower()
mydata
# Out:
#       Education  ...                                      comment_lower
# 0           1.0  ...  yuunivarsitiin  finfinnee fi, hojiilee rakkoo ...
# 1           1.0  ...  ministeerri barnootaa bara baajata 2013tti wal...
# 2           1.0  ...  yuunivarsiitiin maqalee hojii baruuf barsiisuu...
# 3           1.0  ...  bara kana qormaanni biyyaaleessa kutaa 12ffaa ...
# 4           1.0  ...  giiftii dureen itoophiyaa aadde zinnash taayya...
# ...         ...  ...                                                ...
# 5989        0.0  ...  gareen kubbaa miilaa biyyaalessa ityoophiyaa t...
# 5990        0.0  ...   kilabiin kubbaa miilaa dubartootaa baankii da...
# 5991        0.0  ...   kilaboota 8 kan hirmaachisu carraan rammaddii...
# 5992        0.0  ...  shaampiyoonaan atleetiksii kilaboota oromiyaa ...
# 5993        0.0  ...  \n\nispoortii bishaan daakuu ityoophiyaa keess...
#
# [5994 rows x 22 columns]

# %%
import nltk
from nltk import sent_tokenize, word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
mydata['tokenized'] = mydata.apply(lambda row: nltk.word_tokenize(row['comment_lower']), axis=1)
mydata
# Out:
#       Education  ...                                          tokenized
# 0           1.0  ...  [yuunivarsitiin, finfinnee, fi, ,, hojiilee, r...
# 1           1.0  ...  [ministeerri, barnootaa, bara, baajata, 2013tt...
# 2           1.0  ...  [yuunivarsiitiin, maqalee, hojii, baruuf, bars...
# 3           1.0  ...  [bara, kana, qormaanni, biyyaaleessa, kutaa, 1...
# 4           1.0  ...  [giiftii, dureen, itoophiyaa, aadde, zinnash, ...
# ...         ...  ...                                                ...
# 5989        0.0  ...  [gareen, kubbaa, miilaa, biyyaalessa, ityoophi...
# 5990        0.0  ...  [kilabiin, kubbaa, miilaa, dubartootaa, baanki...
# 5991        0.0  ...  [kilaboota, 8, kan, hirmaachisu, carraan, ramm...
# 5992        0.0  ...  [shaampiyoonaan, atleetiksii, kilaboota, oromi...
# 5993        0.0  ...  [ispoortii, bishaan, daakuu, ityoophiyaa, kees...
#
# [5994 rows x 23 columns]

# %%
#to remove emoji
cleaned_data=mydata.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

# %%
cleaned_data
# Out:
#      Education  ...                                          tokenized
# 0          1.0  ...  ['yuunivarsitiin', 'finfinnee', 'fi', ',', 'ho...
# 1          1.0  ...  ['ministeerri', 'barnootaa', 'bara', 'baajata'...
# 2          1.0  ...  ['yuunivarsiitiin', 'maqalee', 'hojii', 'baruu...
# 3          1.0  ...  ['bara', 'kana', 'qormaanni', 'biyyaaleessa', ...
# 4          1.0  ...  ['giiftii', 'dureen', 'itoophiyaa', 'aadde', '...
# ...        ...  ...                                                ...
# 5989       0.0  ...  ['gareen', 'kubbaa', 'miilaa', 'biyyaalessa', ...
# 5990       0.0  ...  ['kilabiin', 'kubbaa', 'miilaa', 'dubartootaa'...
# 5991       0.0  ...  ['kilaboota', '8', 'kan', 'hirmaachisu', 'carr...
# 5992       0.0  ...  ['shaampiyoonaan', 'atleetiksii', 'kilaboota',...
# 5993       0.0  ...  ['ispoortii', 'bishaan', 'daakuu', 'ityoophiya...
#
# [5994 rows x 23 columns]

# %%
dataset=cleaned_data['tokenized']

# %%
dataset = dataset.str.strip()
#dataset['whitespace_removed'] = dataset['tokenized'].str.strip()

# %%
dataset
# Out:
# 0       ['yuunivarsitiin', 'finfinnee', 'fi', ',', 'ho...
# 1       ['ministeerri', 'barnootaa', 'bara', 'baajata'...
# 2       ['yuunivarsiitiin', 'maqalee', 'hojii', 'baruu...
# 3       ['bara', 'kana', 'qormaanni', 'biyyaaleessa', ...
# 4       ['giiftii', 'dureen', 'itoophiyaa', 'aadde', '...
#                               ...
# 5989    ['gareen', 'kubbaa', 'miilaa', 'biyyaalessa', ...
# 5990    ['kilabiin', 'kubbaa', 'miilaa', 'dubartootaa'...
# 5991    ['kilaboota', '8', 'kan', 'hirmaachisu', 'carr...
# 5992    ['shaampiyoonaan', 'atleetiksii', 'kilaboota',...
# 5993    ['ispoortii', 'bishaan', 'daakuu', 'ityoophiya...
# Name: tokenized, Length: 5994, dtype: object

# %%
#to remove white space from the string
def remove_whitespace(dataset):
    """
    Helper function to remove any blank space from a string
   
    """
    try:
        # Remove spaces inside of the string
        x = "".join(dataset.split())

    except:
        pass
    return dataset

dataset= dataset.apply(remove_whitespace)

# %%
dataset
# Out:
# 0       ['yuunivarsitiin', 'finfinnee', 'fi', ',', 'ho...
# 1       ['ministeerri', 'barnootaa', 'bara', 'baajata'...
# 2       ['yuunivarsiitiin', 'maqalee', 'hojii', 'baruu...
# 3       ['bara', 'kana', 'qormaanni', 'biyyaaleessa', ...
# 4       ['giiftii', 'dureen', 'itoophiyaa', 'aadde', '...
#                               ...
# 5989    ['gareen', 'kubbaa', 'miilaa', 'biyyaalessa', ...
# 5990    ['kilabiin', 'kubbaa', 'miilaa', 'dubartootaa'...
# 5991    ['kilaboota', '8', 'kan', 'hirmaachisu', 'carr...
# 5992    ['shaampiyoonaan', 'atleetiksii', 'kilaboota',...
# 5993    ['ispoortii', 'bishaan', 'daakuu', 'ityoophiya...
# Name: tokenized, Length: 5994, dtype: object

# %%
 dataset  = cleaned_data['tokenized']

# %%
#Remover stopwords, criando dicionário de stopwords
def removeStopWords (dataset):
    my_stopwords = pd.read_csv('stp words.csv')
    list_cleaned = set(dataset)-set(my_stopwords)
    return list_cleaned
dataset  = removeStopWords( dataset)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-971ff176ccb0> in <module>()
#       4     list_cleaned = set(dataset)-set(my_stopwords)
#       5     return list_cleaned
# ----> 6 dataset  = removeStopWords( dataset)
#
# <ipython-input-19-971ff176ccb0> in removeStopWords(dataset)
#       1 #Remover stopwords, criando dicionário de stopwords
#       2 def removeStopWords (dataset):
# ----> 3     my_stopwords = pd.read_csv('stp words.csv')
#       4     list_cleaned = set(dataset)-set(my_stopwords)
#       5     return list_cleaned
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stp words.csv'

# %%
import nltk

# %%
stopwords = nltk.corpus.stopwords.words('oromoo')
stopwords
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/util.py in __load(self)
#      79             except LookupError as e:
# ---> 80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      81                 except LookupError: raise e
#
# /usr/local/lib/python3.7/dist-packages/nltk/data.py in find(resource_name, paths)
#     672     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 673     raise LookupError(resource_not_found)
#     674
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-21-4372e6c27b39> in <module>()
# ----> 1 stopwords = nltk.corpus.stopwords.words('oromoo')
#       2 stopwords
#
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     114             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     115
# --> 116         self.__load()
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
#
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/util.py in __load(self)
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
# ---> 81                 except LookupError: raise e
#      82
#      83         # Load the corpus.
#
# /usr/local/lib/python3.7/dist-packages/nltk/corpus/util.py in __load(self)
#      76         else:
#      77             try:
# ---> 78                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#
# /usr/local/lib/python3.7/dist-packages/nltk/data.py in find(resource_name, paths)
#     671     sep = '*' * 70
#     672     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 673     raise LookupError(resource_not_found)
#     674
#     675
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/lib/nltk_data'
# **********************************************************************

# %%
def remove_stopwords(text_tokenized):
    text_clean = [word for word in text_tokenized if word not in stopwords]
    return  text_clean
mydata['non stpwords contents'] = mydata['tokenized'].apply(lambda x: remove_stopwords(x))
mydata.head()

# %% [markdown]
# # CONVERT WORDS IN TO VECTORS

# %%
newsContents = mydata["Contents"].values
newsContents
# Out:
# array(['Yuunivarsitiin  Finfinnee fi, hojiilee rakkoo hawaasaa hiikuu jalqabee cimsuun itti fufu qaba jedhan Pireezidaanti Saahlawarqi Zawdee.Yuunivarsiitiichi hundeeffamaa kan waggaa 70ffaa isaa kabajaa jira.Pireezidaantii Saahlawarqi, Yuunvarsiitiin Finfinnee, yuunvarsiitii hangaafaa ta�uu ibsun, bartootaa Afriikaa baay�eef carraa barnootaa kennuun gumaachaa guddaa taasiseera jedhan.Yuunvarsiitichi yeroo maqaa Yunvaarsiitii Hayila Silaasee 1ffaa jedhame waamama turettis, bartoota akka Afrriikaatti hooggansaaf filaman barsiisuun gahe isa bahaachaaa ture jedhaniiru.',
#        'Ministeerri Barnootaa bara baajata 2013tti walakkaa waggaan baajata harka 55 fayyadamuusaa beeksise.Ministeerichi itti fayyadaminsi baajata idileesaa,itti fayyadama baajata kaappitaalan yoo madaalamu fooyyee akka qabu beeksiseera. Raawwiin karoora hojii bara 2013 baatii ja�aa ministeerichaa akka ibsutti bajata idileesaa harka 72 yoo fayyadamu,baajata kaapitalasaa immoo harka 49 fayyadameera.Baajata idileen deeggarsa hoggansa hojii, misooma barnootan,qulqullina barnootaa mirkaneessuunifi damee misooma bu�uura barnoota babal�isuun Birrii miiliyoona 156fi kuma 795 ol fayyadamuun himameera.',
#        'Yuunivarsiitiin Maqalee hojii baruuf barsiisuu idilee eegaluu beeksiseera.Yuunivarsiitichaatti Daayrekatarri Tajaajila barattoota Dooktar Kasataa Laggasaa hojii baruu fi barsiisuu kan eegalan barattoota kuma 13 eegaman keessaa barattoota hedduu simachuurrratti himuun, barattoonni hafaanis galaa jiraachuu ibsaniiru.',
#        ...,
#        ' Kilaboota 8 kan hirmaachisu Carraan rammaddii nuusa xummuraa Liigii Awurooppaa ifoomeera.\nSagantaa carraa baasuu har�a sa�aatii 9:00 irraa eegalee Siwiizarlaand magaalaa Niyoonitti gaggeeffameen:-\nGiraanaadaa - Maanchiisteer Yuunaayitiid\nArseenaal - Islaaviyaa Prahaa',
#        'Shaampiyoonaan Atleetiksii Kilaboota Oromiyaa 11ffaan Magaalaa Naqamteetti gaggeeffamaa jiraachuu Komishiniin Ispoortii Oromiyaa beeksiise.\nWaldorgommii guyyoota 6f turu kanarratti kilaboonni naannichaa 17 hirmaataniiru.\nSh�ampiyoonaa Istaadiyeemii Wallaggaa Magaalaa Naqamteetti gaggeeffamaa jiru kun Shaampiyoonaa Atleetiksii Ityoophiyaa 50ffaa Atleetoota Oromiyaa bakka bu�uun hirmaatan filachuuf ta�uu ibsameera.\nDorgommii gaggeeffamaa jiru kanarratti Atleetoonni 500 ol hirmaataniiru jedhame.',
#        '\n\nIspoortii Bishaan Daakuu Ityoophiyaa keessatti Abbaa murteessummaa fi leenjisaa ta�uun yeroo dheeraaf kan tajaajilan turan  guyyaa har�aa lubbuun darbuu isaanii Komishiniin Ispoortii Ityoophiyaa beeksiiseera.\n\nInispeektar Sisaay Wayyeessan Kilabni Ispoortii Bishaan Daakaa Poolisii Oromiyaa akka hundaa�u ga�ee olaanaa nama bahaniidha.\n\nKomishiniin Ispoortii FDRI lubbuun darbuu Inispeektar Sisaay Wayyeessan gaddi guddaan itti dhaga�amuu ibseera.'],
#       dtype=object)

# %%
newsvec = [nltk.word_tokenize(Contents)for Contents in newsContents]

# %%
newsvec
# Out:
# [['Yuunivarsitiin',
#   'Finfinnee',
#   'fi',
#   ',',
#   'hojiilee',
#   'rakkoo',
#   'hawaasaa',
#   'hiikuu',
#   'jalqabee',
#   'cimsuun',
#   'itti',
#   'fufu',
#   'qaba',
#   'jedhan',
#   'Pireezidaanti',
#   'Saahlawarqi',
#   'Zawdee.Yuunivarsiitiichi',
#   'hundeeffamaa',
#   'kan',
#   'waggaa',
#   '70ffaa',
#   'isaa',
#   'kabajaa',
#   'jira.Pireezidaantii',
#   'Saahlawarqi',
#   ',',
#   'Yuunvarsiitiin',
#   'Finfinnee',
#   ',',
#   'yuunvarsiitii',
#   'hangaafaa',
#   'ta�uu',
#   'ibsun',
#   ',',
#   'bartootaa',
#   'Afriikaa',
#   'baay�eef',
#   'carraa',
#   'barnootaa',
#   'kennuun',
#   'gumaachaa',
#   'guddaa',
#   'taasiseera',
#   'jedhan.Yuunvarsiitichi',
#   'yeroo',
#   'maqaa',
#   'Yunvaarsiitii',
#   'Hayila',
#   'Silaasee',
#   '1ffaa',
#   'jedhame',
#   'waamama',
#   'turettis',
#   ',',
#   'bartoota',
#   'akka',
#   'Afrriikaatti',
#   'hooggansaaf',
#   'filaman',
#   'barsiisuun',
#   'gahe',
#   'isa',
#   'bahaachaaa',
#   'ture',
#   'jedhaniiru',
#   '.'],
#  ['Ministeerri',
#   'Barnootaa',
#   'bara',
#   'baajata',
#   '2013tti',
#   'walakkaa',
#   'waggaan',
#   'baajata',
#   'harka',
#   '55',
#   'fayyadamuusaa',
#   'beeksise.Ministeerichi',
#   'itti',
#   'fayyadaminsi',
#   'baajata',
#   'idileesaa',
#   ',',
#   'itti',
#   'fayyadama',
#   'baajata',
#   'kaappitaalan',
#   'yoo',
#   'madaalamu',
#   'fooyyee',
#   'akka',
#   'qabu',
#   'beeksiseera',
#   '.',
#   'Raawwiin',
#   'karoora',
#   'hojii',
#   'bara',
#   '2013',
#   'baatii',
#   'ja�aa',
#   'ministeerichaa',
#   'akka',
#   'ibsutti',
#   'bajata',
#   'idileesaa',
#   'harka',
#   '72',
#   'yoo',
#   'fayyadamu',
#   ',',
#   'baajata',
#   'kaapitalasaa',
#   'immoo',
#   'harka',
#   '49',
#   'fayyadameera.Baajata',
#   'idileen',
#   'deeggarsa',
#   'hoggansa',
#   'hojii',
#   ',',
#   'misooma',
#   'barnootan',
#   ',',
#   'qulqullina',
#   'barnootaa',
#   'mirkaneessuunifi',
#   'damee',
#   'misooma',
#   'bu�uura',
#   'barnoota',
#   'babal�isuun',
#   'Birrii',
#   'miiliyoona',
#   '156fi',
#   'kuma',
#   '795',
#   'ol',
#   'fayyadamuun',
#   'himameera',
#   '.'],
#  ['Yuunivarsiitiin',
#   'Maqalee',
#   'hojii',
#   'baruuf',
#   'barsiisuu',
#   'idilee',
#   'eegaluu',
#   'beeksiseera.Yuunivarsiitichaatti',
#   'Daayrekatarri',
#   'Tajaajila',
#   'barattoota',
#   'Dooktar',
#   'Kasataa',
#   'Laggasaa',
#   'hojii',
#   'baruu',
#   'fi',
#   'barsiisuu',
#   'kan',
#   'eegalan',
#   'barattoota',
#   'kuma',
#   '13',
#   'eegaman',
#   'keessaa',
#   'barattoota',
#   'hedduu',
#   'simachuurrratti',
#   'himuun',
#   ',',
#   'barattoonni',
#   'hafaanis',
#   'galaa',
#   'jiraachuu',
#   'ibsaniiru',
#   '.'],
#  ['Bara',
#   'kana',
#   'qormaanni',
#   'biyyaaleessa',
#   'Kutaa',
#   '12ffaa',
#   'karaa',
#   'onlaayiinii',
#   'kennaamuun',
#   'hafeeera.Ministirri',
#   'Barnootaa',
#   'Dr.',
#   'Injinaar',
#   'Geetaahuun',
#   'Makuuriyaa',
#   'akka',
#   'himanitti',
#   'qormaata',
#   'biyyaaleessaa',
#   'kutaa',
#   '12ffa',
#   'bara',
#   'kanaa',
#   'kennuuf',
#   'ministeerrichi',
#   'karaa',
#   'teekinolojiitiin',
#   'karoora',
#   'qabatee',
#   'turus',
#   'sababaa',
#   'Vaayrasii',
#   'koroonaatiin',
#   'taabileetonni',
#   'ittin',
#   'qoramanni',
#   'kennaamuuf',
#   'yaadame',
#   'yeroon',
#   'gara',
#   'biyyaatti',
#   'galichuu',
#   'waan',
#   'danda�amneef',
#   'waraqaadhaan',
#   'qormaata',
#   'kennuuf',
#   'mirteeffamera',
#   '.'],
#  ['Giiftii',
#   'Dureen',
#   'Itoophiyaa',
#   'aadde',
#   'Zinnash',
#   'Taayyachaw',
#   'naannoo',
#   'Oromiyaa',
#   'godina',
#   'Shawaa',
#   'Lixaa',
#   'aanaa',
#   'Ambootti',
#   'mana',
#   'barumsaa',
#   'sadarkaa',
#   '2ffaa',
#   'ijaaruuf',
#   'dhagaa',
#   'bu�uraa',
#   'ka�aniiru.Aanaa',
#   'Ambootti',
#   'ijaarsa',
#   'mana',
#   'barumsaa',
#   'Ifaa',
#   'Goromtiif',
#   'dhagaa',
#   'bu�uraa',
#   'kan',
#   'ka�an.Ijaarsi',
#   'mana',
#   'barumsichaas',
#   'ganda',
#   'Booruu',
#   'Goramtii',
#   'bakka',
#   'dhaloota',
#   'Looreet',
#   'Tsaggayee',
#   'Gabra',
#   'Madiidha',
#   '.'],
#  ['Yuunivarsiitiin',
#   'Addigiraat',
#   'yeroo',
#   '8ffaa',
#   'barattoota',
#   'barsiisaa',
#   'ture',
#   '2576',
#   'eebbise.Yuunivarsiitichi',
#   'tarkaanfii',
#   'mootummaan',
#   'olaantummaa',
#   'seera',
#   'Kabachiisuu',
#   'naannoo',
#   'Tigiraayitti',
#   'fedhate',
#   'hordofuun',
#   'garee',
#   'ABUTn',
#   'waan',
#   'miidhan',
#   'irra',
#   'gaheef',
#   'baratoota',
#   'barsiisaa',
#   'ture',
#   'barnoota',
#   'isaan',
#   'hafee',
#   'Yuunivarsiiti',
#   'Maqaleetti',
#   'barsiisun',
#   'eebbisera.Sirna',
#   'eebbaa',
#   'kanarratti',
#   'Ministirri',
#   'Saayinsii',
#   'fi',
#   'Barnoota',
#   'Olaanoo',
#   'Dooktar',
#   'Saamu�eel',
#   'Urqaatoo',
#   ',',
#   'hojii',
#   'raawwachiisaa',
#   'olaanaa',
#   'Bulchiinsa',
#   'Yeroo',
#   'Naannoo',
#   'Tigiraay',
#   'Dooktar',
#   'Muluu',
#   'Naggaa',
#   'fi',
#   'keessuummoonni',
#   'argamaniiru.Gama',
#   'biraatiin',
#   'dhihoo',
#   'kana',
#   'baratoota',
#   'kan',
#   'eebbisee',
#   'Yuunivarsiitiin',
#   'Maqalees',
#   'baratoota',
#   '608',
#   'hafaan',
#   'marsaa',
#   'lammaffaaf',
#   'eebbiseera',
#   '.'],
#  ['Dhaabbileen',
#   'barnoota',
#   'olaanoon',
#   'har�a',
#   'baratoota',
#   'eebbisisaniiru.Haluma',
#   'kanaan',
#   'Yuunvarsiitiin',
#   'Bahaar',
#   'Dar',
#   ',',
#   'Dabaariq',
#   'fi',
#   'Waldaayaa',
#   'barattoota',
#   'ogummaa',
#   'garaagaraan',
#   'barsiisaa',
#   'turan',
#   'kuma',
#   '8',
#   'fi',
#   '674',
#   'eebbisiisaniiru.Baay�inni',
#   'baratoota',
#   'Yuunivarsiitiin',
#   'Bahaar',
#   'Dar',
#   'eebbisisee',
#   'walii',
#   'galaan',
#   'kuma',
#   '5',
#   'fi',
#   '117',
#   'dha.Kanneen',
#   'keessaas',
#   'kuma',
#   '1',
#   'fi',
#   '623',
#   'jedhamera.Yuunivarsiitiin',
#   'Dabaarqis',
#   'baratoota',
#   'gosa',
#   'ogummaa',
#   'adda',
#   'addaan',
#   'barsiisaa',
#   'ture',
#   'digirii',
#   'jalqabaan',
#   'baratoota',
#   '773',
#   'yeroo',
#   'jalqabaaf',
#   'eebbisiiseera',
#   '.'],
#  ['Giiftii',
#   'Duree',
#   'Zinnash',
#   'Taayyaachoo',
#   'mana',
#   'barumsaa',
#   'fedhii',
#   'addaa',
#   'Gidduugala',
#   'Faawundeshinii',
#   'Diiboraa',
#   'eegalsiisan.Waajjirri',
#   'Giiftii',
#   'Duree',
#   'kallattiiwwan',
#   'xiyyeeffannoon',
#   'hojjechuuf',
#   'karoorfate',
#   'keessaa',
#   'tokko',
#   'nageenyaafi',
#   'kunuunsa',
#   'Fayyaa',
#   'sammuurrattidha.Haaluma',
#   'kanaan',
#   'mana',
#   'barumsaa',
#   'fedhii',
#   'addaa',
#   'Gidduugala',
#   'Fawundeeshinii',
#   'Dibooraa',
#   'naannawaa',
#   'Laga',
#   'Xaafootti',
#   'argamu',
#   'daa�immaniifi',
#   'dargaggoota',
#   'rakkoo',
#   'sammuu',
#   'qaban',
#   'kan',
#   'tajaajilu',
#   'ijaaruuf',
#   'dhagaa',
#   'bu�uraa',
#   'kaahuun',
#   'ijaarsasaa',
#   'eegalsiisaniiru',
#   '.'],
#  ['Naanno',
#   'Affar',
#   'Godina',
#   'Awsuu-Rasuu',
#   'Magaalaa',
#   'Dubtitti',
#   'manni',
#   'barnootaa',
#   'sadarkaa',
#   '2ffaa',
#   'Waajjira',
#   'Giifti',
#   'Dureen',
#   'ijaarame',
#   'eebbifame.Manni',
#   'barnoota',
#   'kun',
#   'mana',
#   'barnoota',
#   'waajjira',
#   'Giifti',
#   'dureen',
#   'ijaramee',
#   'eebbifame',
#   'isa',
#   '13ffadha',
#   'jedhamera',
#   '.'],
#  ['Lammiin',
#   'kutaa',
#   '12',
#   'fi',
#   'sanaa',
#   'ol',
#   'barate',
#   'hundinuu',
#   'rakkoo',
#   'hanqina',
#   'barsiisotaa',
#   'sababa',
#   'vaayirasii',
#   'koronaan',
#   'mudatu',
#   'furuuf',
#   'barnoota',
#   'barsiisuurratti',
#   'hirmaachuu',
#   'akka',
#   'qabu',
#   'Ministeerri',
#   'barnootaa',
#   'dhaame.Jilli',
#   'ministeera',
#   'Barnootaa',
#   'fi',
#   'Biiroo',
#   'Barnootaa',
#   'Oromiyaan',
#   'durfamu',
#   'qophii',
#   'barnoota',
#   'bara',
#   '2013�f',
#   'magaalaa',
#   'Adaamaatti',
#   'taasifamaa',
#   'jiru',
#   'daawwate',
#   '.'],
#  ['Yuunivarsiitiin',
#   'Dillaa',
#   'barattoota',
#   'kuma',
#   '3',
#   'fi',
#   '500',
#   'ol',
#   'barsiisaa',
#   'ture',
#   'eebbisaa',
#   'jira.Yuunivarsiitichi',
#   'barattoota',
#   'sagantaa',
#   'idilee',
#   'fi',
#   'al-idileen',
#   'barsiisaa',
#   'ture',
#   'digiri',
#   'jalqabaafi',
#   'digiri',
#   'lammaffaa',
#   'barnoota',
#   'isaanii',
#   'xumurani',
#   'kan',
#   'eebbise.Sirna',
#   'eebbaa',
#   'kana',
#   'irrattis',
#   'Naannoo',
#   'Kibbaatti',
#   'Sadarkaa',
#   'Pireezdaanti',
#   'Itti',
#   'Aanaatti',
#   'Qindeessaa',
#   'Kilaastara',
#   'Hawaasummaa',
#   'fi',
#   'Hoggannaan',
#   'Biiroo',
#   'Aadaafi',
#   'Tuurizimii',
#   'Obbo',
#   'Haayilamaaram',
#   'Tasfaayee',
#   'dabalate',
#   'miseenssooni',
#   'Boordii',
#   'Yuunivarsiichaa',
#   'fi',
#   'hoogganttoonni',
#   'olaanoo',
#   'naannichaa',
#   'argamaniiru',
#   '.'],
#  ['Bu�aan',
#   'qormaata',
#   'naannoo',
#   'kutaa',
#   '8ffaa',
#   'naannoo',
#   'Oromiyaa',
#   'beekkamuu',
#   'Biiroon',
#   'Barnootaa',
#   'naannoo',
#   'Oromiyaa',
#   'beeksise.Qormaatni',
#   'Sadaasa',
#   '30',
#   'hanga',
#   'Muddee',
#   '2',
#   ',',
#   '2013tti',
#   'guutummaa',
#   'Oromiyaatti',
#   'kennamee',
#   'ture',
#   'bu�aan',
#   'isaa',
#   'beekkameera',
#   '.',
#   'Waraqaan',
#   'deebii',
#   'kallattii',
#   'Oromiyaa',
#   'hunda',
#   'irraa',
#   'Manneen',
#   'Barnootaa',
#   'kuma',
#   '8',
#   'ol-irraa',
#   'aanaatti',
#   ',',
#   'aanaa',
#   'irraa',
#   'godinatti',
#   ',',
#   'godina',
#   'irraa',
#   'BBOtti',
#   'sassaabamee',
#   'torban',
#   '3',
#   'keessatti',
#   'halkanii',
#   'fi',
#   'guyyaa',
#   'shiftii',
#   '3n',
#   'biiroo',
#   'keessa',
#   'bulaa',
#   'hojjetamee',
#   'har�a',
#   'bu�aan',
#   'isaa',
#   'beekameera',
#   '.'],
#  ['Yuunivarsitiin',
#   'Bulee',
#   'Horaa',
#   'barattoota',
#   'mummee',
#   'Teknooloojii',
#   'Meedikaal',
#   'Raadiyoolojii',
#   'sagantaa',
#   'digirii',
#   'lammaffaan',
#   'barsiisuu',
#   'har�a',
#   'jalqabsise.Yuunivarsitiichi',
#   'muummee',
#   'Teeknooloojii',
#   'Meediikaal',
#   'Raadiyooloojistitin',
#   'digirii',
#   'lammaffaa',
#   'barsisuutiin',
#   'yuunivarsitoota',
#   'biyya',
#   'keenyarraa',
#   'isa',
#   'jalqabaa',
#   'akka',
#   'tahee',
#   'fi',
#   'yeroo',
#   'jalqabaaf',
#   'sagantaa',
#   'kanaan',
#   'barattoota',
#   '10',
#   'simatee',
#   'kan',
#   'barsisuu',
#   'yogguu',
#   'ta�u',
#   '10',
#   'keessa',
#   '2',
#   'shammarran',
#   'akka',
#   'tahe',
#   'yuunivarsitii',
#   'Bulee',
#   'Horaatti',
#   'Diiniin',
#   'Koolleejjii',
#   'Fayyaa',
#   'obbo',
#   'Taakkalaa',
#   'Uturaa',
#   'himaniru',
#   '.'],
#  ['Yuunivarsitiin',
#   'Bulee',
#   'Horaa',
#   'barattoota',
#   'mummee',
#   'Teknooloojii',
#   'Meedikaal',
#   'Raadiyoolojii',
#   'sagantaa',
#   'digirii',
#   'lammaffaan',
#   'barsiisuu',
#   'har�a',
#   'jalqabsise.Yuunivarsitiichi',
#   'muummee',
#   'Teeknooloojii',
#   'Meediikaal',
#   'Raadiyooloojistitin',
#   'digirii',
#   'lammaffaa',
#   'barsisuutiin',
#   'yuunivarsitoota',
#   'biyya',
#   'keenyarraa',
#   'isa',
#   'jalqabaa',
#   'akka',
#   'tahee',
#   'fi',
#   'yeroo',
#   'jalqabaaf',
#   'sagantaa',
#   'kanaan',
#   'barattoota',
#   '10',
#   'simatee',
#   'kan',
#   'barsisuu',
#   'yogguu',
#   'ta�u',
#   '10',
#   'keessa',
#   '2',
#   'shammarran',
#   'akka',
#   'tahe',
#   'yuunivarsitii',
#   'Bulee',
#   'Horaatti',
#   'Diiniin',
#   'Koolleejjii',
#   'Fayyaa',
#   'obbo',
#   'Taakkalaa',
#   'Uturaa',
#   'himaniru',
#   '.'],
#  ['Dhaabbilee',
#   'Barnoota',
#   'Olaanootti',
#   'konfiraansiin',
#   'Qorannoo',
#   'Biyyoolessaa',
#   '3ffaan',
#   'Adaamaatti',
#   'taa�amaa',
#   'jira',
#   'Waltajjicharrattis',
#   'Dhaabbileen',
#   'saayinsiifi',
#   'Barnoota',
#   'Olaanoo',
#   'irratti',
#   'hirmaatanii',
#   'jiru.Waraqaan',
#   'Qorannoos',
#   'Hayyootaan',
#   'dhiyaateera',
#   ';',
#   'ciminni',
#   'hedduun',
#   'jiraatuus',
#   ',',
#   'hanqinaaleen',
#   'Dhaabbilee',
#   'Barnootaa',
#   'Mootummaafi',
#   'Dhuunfaa',
#   'keessatti',
#   'mul�atan',
#   'kanneen',
#   'akka',
#   'rakkoo',
#   'qulqullina',
#   'nyaataafi',
#   'yeroon',
#   'dhiyeessuu',
#   'dhabuu',
#   ',',
#   'rakkoo',
#   'bulchiinsa',
#   ',',
#   'rakkoon',
#   'bulchiinsa',
#   'mul�achuu',
#   ',',
#   'Hanqina',
#   'doormiterii',
#   'mul�achuu',
#   'dhiyaateera',
#   '.'],
#  ['Ministirri',
#   'Deetaan',
#   'Dhaabbilee',
#   'Saayinsiifi',
#   'Barnoota',
#   'Olaanoo',
#   'Dr',
#   'Saamu�eel',
#   'Kifilee',
#   'Dhaabbilee',
#   'Barnootaaf',
#   'qorannoofi',
#   'leenjiin',
#   'ajandaa',
#   'ijoodhaa',
#   'jedhan',
#   '.',
#   'Jijjiirama',
#   'barbaadamu',
#   'fiduuf',
#   'qindoominni',
#   'qaamolee',
#   'hundaa',
#   'murteessaadhaa',
#   'jedhan',
#   '.'],
#  ['Sirna',
#   'qabiinsa',
#   'ragaa',
#   'dhaabbilee',
#   'barnoota',
#   'olaanoo',
#   'ammeeyyeessuf',
#   'sagantaan',
#   'gochaa',
#   'ifoomeSirna',
#   'qabiinsa',
#   'ragaa',
#   'Dhaabbilee',
#   'Barnoota',
#   'Olaanoo',
#   'ammeeyyeessuf',
#   'sagantaa',
#   'gochaa',
#   'Fulbaana',
#   '4',
#   ',',
#   '2013',
#   'hanga',
#   'Fulbaana',
#   '23',
#   ',',
#   '2013tti',
#   'turu',
#   ',',
#   'hoggantoota',
#   'hojii',
#   'olaanoo',
#   'Yuunivarsiitiwwanii',
#   'kuma',
#   '5',
#   'ol',
#   'hirmaachisu',
#   'har�a',
#   'ifoome',
#   '.'],
#  ['Niijeer',
#   'Fadjii',
#   'Maayinaa',
#   ',',
#   'dubartii',
#   'Afriikaa',
#   'jalqabaa',
#   'jabduu',
#   'dhaabbata',
#   'hawaa',
#   'fi',
#   'wantoota',
#   'hawaa',
#   'keessa',
#   'jiran',
#   'qoratu',
#   '(',
#   'NASA',
#   ')',
#   'keessatti',
#   'qacaramtee',
#   'hojjetaa',
#   'jirtu',
#   'taateetti.Haayidirooloojistiin',
#   'umrii',
#   'waggaa',
#   '29',
#   'kun',
#   'digiriishee',
#   'sadaffaa',
#   '(',
#   'PhD',
#   ')',
#   'bara',
#   'Faranjoota',
#   '2016',
#   'argatte.Dhaabbata',
#   'addunyaarratti',
#   'beekamaa',
#   'ta�e',
#   'NASA',
#   'kan',
#   'US',
#   'keessatti',
#   'argamu',
#   'ammoo',
#   'dhuma',
#   'ji�a',
#   'darbee',
#   'seente.Carraa',
#   'hojii',
#   'argatte',
#   'kanaan',
#   'biyyashee',
#   'fi',
#   'ardii',
#   'Afriikaa',
#   'akka',
#   'gargaaruuf',
#   'karoorfatte',
#   'dubbatte',
#   'Fadji',
#   'Mayina',
#   '.'],
#  ['Manneen',
#   'barnootaa',
#   'kaffaltii',
#   'seera',
#   'alaa',
#   'dabalanirrattii',
#   'tarkaanfii',
#   'hanga',
#   'mana',
#   'barumsaa',
#   'cufuu',
#   'hordofsiisa',
#   "''",
#   'Ministeera',
#   'Barnootaa.Ministeerri',
#   'barnootaa',
#   'komiiwwan',
#   'maatii',
#   'barattootarraa',
#   'ka�u',
#   'bu�uura',
#   'godhachuun',
#   'tarkaanfii',
#   'akka',
#   'fudhatu',
#   'beekiseera.Deetaan',
#   'Ministeera',
#   'Barnootaa',
#   'Obbo',
#   'Miiliyoon',
#   'Maatiwoos',
#   'dhimma',
#   'barnootaa',
#   'bara',
#   'itti',
#   'aanuurratti',
#   'miidiyaaf',
#   'ibsa',
#   'kennaniiru',
#   '.'],
#  ['Ministeerri',
#   'barnootaa',
#   'rakkoo',
#   'itti',
#   'fayyadama',
#   'bajataa',
#   'dhaabbilee',
#   'barnootaa',
#   'ol',
#   'aanaa',
#   'keessatti',
#   'mul�atu',
#   'fooyyessuu',
#   'akka',
#   'hin',
#   'dandeenye',
#   'ibsame.Manni',
#   'maree',
#   'bakka',
#   'bu�oota',
#   'uummataa',
#   'koree',
#   'qindoominaa',
#   'kan',
#   'yeroo',
#   ',',
#   'hojmaata',
#   ',',
#   'furmaata',
#   'argannoo',
#   'odiitii',
#   'dhaabbilee',
#   'barnoota',
#   'olaanaa',
#   'waliin',
#   'maree',
#   'adeemsiseera',
#   '.',
#   'Koreen',
#   'hundaa�e',
#   'kun',
#   'baatii',
#   'jaa�aaf',
#   'argannoo',
#   'odiitii',
#   'dhaabbilee',
#   'barnootaa',
#   'olaanaa',
#   'irratti',
#   'hordoffii',
#   'fi',
#   'to�annoo',
#   'gochaa',
#   'turuun',
#   'isaa',
#   'hubatameera',
#   '.'],
#  ['Qormaata',
#   'biyyoolessaa',
#   'kutaa',
#   '12ffaa',
#   'kallattii',
#   'intarneetiin',
#   'laachuuf',
#   'qophiin',
#   'xumuramuu',
#   'Ministeerri',
#   'Barnootaa',
#   'FDRI',
#   'beeksise.Qormaata',
#   'kutaa',
#   '12ffaa',
#   'bara',
#   '2012',
#   'kallattiin',
#   'laachuuf',
#   'dhiyeessiin',
#   'ibsaa',
#   'fi',
#   'intarneetii',
#   'akka',
#   'mijatu',
#   'hojjetamaa',
#   'jira',
#   'jedheera',
#   '.'],
#  ['Dhaabbileen',
#   'Barnoota',
#   'Olaanoo',
#   'sirna',
#   'qabiinsa',
#   'ragaa',
#   'ammayyeessuu',
#   'fi',
#   'ragaa',
#   'sirriin',
#   'akka',
#   'walga�u',
#   'gochuuf',
#   'hojii',
#   'fakkeenyummaa',
#   'hojjechuu',
#   'akka',
#   'qaban',
#   'irraa',
#   'eegama',
#   'jedhameera.Baruu',
#   'fi',
#   'barsiisuu',
#   ',',
#   'qorannoo',
#   'fi',
#   'tajaajila',
#   'hunda',
#   'galeessa',
#   'hawaasaa',
#   'keessatti',
#   'hojiiwwan',
#   'hojjetaman',
#   'ragaa',
#   'sirriin',
#   'qabanii',
#   'karaa',
#   'ammayyaa�aan',
#   'akkasumaas',
#   'kutaa',
#   'dhimmi',
#   'ilaallatuuf',
#   'aadaa',
#   'dabarsuu',
#   'shakaluun',
#   'barbaachisaa',
#   'akka',
#   'ta�ee',
#   'eerameera',
#   '.'],
#  ['Yunivarsitiin',
#   'Madda',
#   'Walaabuu',
#   'sirna',
#   'baruufi',
#   'barsiisuu',
#   'bara',
#   'kanaa',
#   'akkaataa',
#   'milkeessuun',
#   'danda�amurratti',
#   'qaamolee',
#   'hawaasa',
#   'garagaraa',
#   'waliin',
#   'magaalaa',
#   'Roobeetti',
#   'mari�ate.Qooda',
#   'fudhattoonni',
#   'marichaa',
#   'irratti',
#   'hirmaatan',
#   'yaada',
#   'kennaniin',
#   'barattoonni',
#   'Yunivarsitii',
#   'Madda',
#   'Walaabuutti',
#   'baratan',
#   'barnoota',
#   'isaanii',
#   'karaa',
#   'tasgabbaa�aa',
#   'ta�een',
#   'akka',
#   'barataniif',
#   'gahee',
#   'irraa',
#   'eeggamu',
#   'kan',
#   'bahan',
#   'ta�uu',
#   'himan',
#   '.'],
#  ['Barattoonni',
#   'Godina',
#   'Iluu',
#   'Abba',
#   'Boor',
#   'qormaata',
#   'biyyaalessaa',
#   'barana',
#   'fudhatan',
#   'firii',
#   'ol�aanaa',
#   'galmeessuuf',
#   'raayyaa',
#   'misooma',
#   'barnootaan',
#   'qo�aachaa',
#   'akka',
#   'jira',
#   'himan.Barsiisonnii',
#   'fi',
#   'maatiin',
#   'barattootaa',
#   'paakeejjii',
#   'mirkaneeffannaa',
#   'qulqullina',
#   'barnootaa',
#   'qabatamaan',
#   'hojirraa',
#   'oolchuuf',
#   'gahee',
#   'isaanii',
#   'gummaacha',
#   'akka',
#   'jiran',
#   ',',
#   'waajjirri',
#   'barnoota',
#   'Godinichaa',
#   'beeksiseera',
#   '.'],
#  ['Godina',
#   'Gujii',
#   'bulchiinsa',
#   'magaalaa',
#   'nageelleetti',
#   'barattoonni',
#   'mana',
#   'barumsa',
#   'sadarka',
#   '1ffaa',
#   'makaana',
#   'iyyasus',
#   'qormaata',
#   'kuta',
#   '8ffaa',
#   'barana',
#   'irratti',
#   'qabxii',
#   'gaarii',
#   'galmesisuf',
#   'rayyaa',
#   'barnoottaan',
#   'qo�achaa',
#   'jiraachu',
#   'dubbatan.Barattoonni',
#   'bulchiinsa',
#   'magaalicha',
#   'kuma',
#   '1',
#   'fi',
#   '700',
#   'ol',
#   'ta�an',
#   'qormata',
#   'kuta',
#   '8ffaa',
#   'fi',
#   'biyoolessa',
#   'baran',
#   'akka',
#   'fudhatan',
#   'waajjirri',
#   'barnoota',
#   'bulchiinsa',
#   'magaalaa',
#   'Nageellee',
#   'beekiseera',
#   '.'],
#  ['Barattoonni',
#   'yugaandaa',
#   'lama',
#   'qorannoo',
#   'wantoota',
#   'gataman',
#   'irraa',
#   'boba�aa',
#   'oomishuurratti',
#   'qoratan',
#   ',',
#   'hojiitti',
#   'jijjiiraa',
#   'jiru',
#   '.',
#   'Qorannoon',
#   'muraasni',
#   'isa',
#   'hafus',
#   'boba�aan',
#   'isaan',
#   'oomishan',
#   'bu�a',
#   'qabeessa',
#   'ta�uun',
#   'shaakalliin',
#   'mirkanaa�eera'],
#  ['Qormaata',
#   'biyaleessaan',
#   'qabxii',
#   'gaarii',
#   'fiduuf',
#   'raayyaan',
#   'qo�achaa',
#   'akka',
#   'jiran',
#   'barattoonni',
#   'aanaalee',
#   'Daallee',
#   'Waabaraa',
#   'fi',
#   'Hawwaa',
#   'Galaan',
#   'himan',
#   'Godina',
#   'Qeellem',
#   'Wallaggaatti',
#   'bara',
#   'kana',
#   'barattoonni',
#   'kuma',
#   '13',
#   'ol',
#   'qormaata',
#   'biyyaalessaa',
#   'kutaa',
#   '10ffaa',
#   'fi',
#   '12ffaa',
#   'qoramuuf',
#   'qophaa�aa',
#   'jiru',
#   '.'],
#  ['Baratoonni',
#   'kutaa',
#   '10ffaa',
#   'fi',
#   '12ffaa',
#   'Aanaa',
#   'Abbayyaa',
#   ',',
#   'qoramaata',
#   'biyyaleessaaf',
#   'raayyaasaaniin',
#   'qo�achuun',
#   'of',
#   'qopheessaa',
#   'akka',
#   'jiran',
#   'himan.Barattoota',
#   'kanneen',
#   'gama',
#   'hundaan',
#   'deeggaraa',
#   'akka',
#   'jiru',
#   'Waajjirri',
#   'Barnoota',
#   'Aanichaa',
#   'beeksise',
#   '.'],
#  ['Yunivarsittin',
#   'arsii',
#   'qorannoo',
#   'fi',
#   'qo�annoo',
#   'rakkoo',
#   'hawaas-dinagdee',
#   'uummataa',
#   'faana',
#   'qorachun',
#   'fayyadamuun',
#   'hawaasa',
#   'mirkanessuuf',
#   'hojjacha',
#   'jiraachuu',
#   'beeksise'],
#  ['Barattoonni',
#   'aanaalee',
#   'Guutoo',
#   'Giddaa',
#   'fi',
#   'Qimbibiit',
#   'qormaata',
#   'biyyaalessaa',
#   'fudhatan',
#   ',',
#   'qabxii',
#   'gaarii',
#   'akka',
#   'argataniif',
#   'hojjetamaa',
#   'jira',
#   'jedhameera.Barattoonnis',
#   'kana',
#   'milkeessuuf',
#   'sirnaan',
#   'qu�achaa',
#   'akka',
#   'jiran',
#   'himan'],
#  ['Aanaa',
#   'Warraa',
#   'jaarsootti',
#   'barattoonni',
#   'manneen',
#   'barnootaa',
#   'gohatsiyoon',
#   'raayyaan',
#   'qo�achuunn',
#   'qormaata',
#   'biyyoleessaa',
#   'qophaa�aa',
#   'akka',
#   'jiran',
#   'himan.Godina',
#   'Shawaa',
#   'kaabaatti',
#   'baranaa',
#   'kana',
#   'barattoonni',
#   'kumni',
#   '12',
#   'ol',
#   'qormaata',
#   'naannoo',
#   'fi',
#   'biyyalessaa',
#   'fudhatu',
#   '.'],
#  ['Baratoonni',
#   'Godina',
#   'Harargee',
#   'Lixaa',
#   'Aanaa',
#   'Horsiisee',
#   'bulaa',
#   'burqaa',
#   'dhiintuu',
#   'qormata',
#   'biyyoolessaa',
#   'fi',
#   'naannootiif',
#   'of',
#   'qopheesaa',
#   'jiraachuu',
#   'himaniiru'],
#  ['Godina',
#   'Gujii',
#   'bulchiinsa',
#   'magaalaa',
#   'nageelleetti',
#   'barattoonni',
#   'mana',
#   'barumsa',
#   'sadarka',
#   '1ffaa',
#   'makaana',
#   'iyyasus',
#   'qormaata',
#   'kuta',
#   '8ffaa',
#   'barana',
#   'irratti',
#   'qabxii',
#   'gaarii',
#   'galmesisuf',
#   'rayyaa',
#   'barnoottaan',
#   'qo�achaa',
#   'jiraachu',
#   'dubbatan',
#   '.'],
#  ['Baratoonni',
#   'godinaa',
#   'harargee',
#   'lixaa',
#   'aanaa',
#   'horsiisee',
#   'bulaa',
#   'burqaa',
#   'dhintuu',
#   'nyaatni',
#   'maneen',
#   'barnoota',
#   'keessatti',
#   'nu',
#   'dhiyaata',
#   'jiru',
#   'barnoota',
#   'keenyaa',
#   'sinaan',
#   'akka',
#   'hordoofnuu',
#   'nu',
#   'taasiseera',
#   'jedhan',
#   '.'],
#  ['Barattoonni',
#   'Aanaa',
#   'Miyoo',
#   'fi',
#   'magaalaa',
#   'Sandaafaa',
#   'bakkee',
#   'kutaa',
#   '10ffaa',
#   'fi',
#   '12ffaan',
#   'qormaata',
#   'biyyaalessaaf',
#   'raayyaan',
#   'qo�achuun',
#   'qophaa�aa',
#   'jirra',
#   'jedhan',
#   'Efreem',
#   'Tafarra',
#   '.'],
#  ['Manneen',
#   'barnootaa',
#   'kutaalee',
#   'magaalaa',
#   'Finfinnee',
#   'shan',
#   'keessatti',
#   ',',
#   'biiroo',
#   'barnootaa',
#   'Oromiyaan',
#   'ijaaramaa',
#   'jiran',
#   'keessaa',
#   ',',
#   'manneen',
#   'barnootaa',
#   '2',
#   'ijaarsi',
#   'isaanii',
#   'xumuramanii',
#   'tajaajilaaf',
#   'qophaa�uu',
#   ',',
#   'Biiroon',
#   'Barnootaa',
#   'Oromiyaa',
#   'beeksise',
#   '.'],
#  ['Barattoonni',
#   'qormaata',
#   'biyyaalessaa',
#   'kutaa',
#   '8ffaa',
#   ',',
#   '10ffaa',
#   'fi',
#   'qormaata',
#   'seensaa',
#   'kutaa',
#   '12ffaa',
#   'baranaa',
#   'fudhatan',
#   ',',
#   'qabxii',
#   'gaarii',
#   'akka',
#   'galmeessaniif',
#   'hojjetamaa',
#   'akka',
#   'jiru',
#   ',',
#   'Birroon',
#   'Barnootaa',
#   'Oromiyaa',
#   'beeksise.Hawaasni',
#   'barnootaa',
#   ',',
#   'barattoota',
#   'gama',
#   'xiin-sammuu',
#   'fi',
#   'beekumsaan',
#   'qopheessuu',
#   'irratti',
#   'gaheesaa',
#   'gumaachuu',
#   'akka',
#   'qabus',
#   'biirichi',
#   'hubachiiseera.Huseen',
#   'Kamaal',
#   ',',
#   'dabalata',
#   'qaba',
#   '.'],
#  ['Barattoonni',
#   'godina',
#   'Arsii',
#   'raayyaa',
#   'barnootaan',
#   'gurma�anii',
#   'qu�achuun',
#   'qabxiin',
#   'isaanii',
#   'fooyya�aa',
#   'akka',
#   'jiru',
#   'himan.Baranaa',
#   'godinichatti',
#   ',',
#   'barattoonni',
#   'kuma',
#   '26',
#   'ol',
#   'qoramataa',
#   'biyyaaleessaa',
#   'akka',
#   'fudhatan',
#   'waajjirri',
#   'barnoota',
#   'godinichaa',
#   'beeksisera'],
#  ['Yaa�iin',
#   'idilee',
#   'gamtaa',
#   'barattoota',
#   'dhaabbilee',
#   'barnoota',
#   'olaanoo',
#   '27ffaan',
#   'guyyoota',
#   'sadiif',
#   'yuunivaarsiitii',
#   'Madda',
#   'Walaabuutti',
#   'taa�amaa',
#   'ture',
#   'kallattii',
#   'hojii',
#   'fuula',
#   'dura',
#   'kaa�uun',
#   'xumurame',
#   '.'],
#  ['Barattoonni',
#   'manneen',
#   'barnoota',
#   'aanaalee',
#   'Booraa',
#   'fi',
#   'Ada�aa',
#   'Bargaa',
#   'qorumsa',
#   'biyyolessaa',
#   'qabxii',
#   'gaarii',
#   'galmeessuuf',
#   'raayyaa',
#   'barnootaan',
#   'qo�achaa',
#   'akka',
#   'jiran',
#   'himan',
#   '.'],
#  ['Godina',
#   'Iluu',
#   'Abbaa',
#   'Boor',
#   'aanaa',
#   'Dooranniitti',
#   'barnoonni',
#   'idileen',
#   'duraa',
#   'kennamuun',
#   'daa�imman',
#   'isaanii',
#   'fedhii',
#   'fi',
#   'kaka�umsa',
#   'barnootaa',
#   'akka',
#   'horatan',
#   'gocha',
#   'jiraachuu',
#   'jiraattonni',
#   'himan.Godinichatti',
#   'barana',
#   'daa�imman',
#   'kuma',
#   '46',
#   'caalan',
#   'barnoota',
#   'idileen',
#   'duraa',
#   'hordofaa',
#   'jiraachuus',
#   'waajjirri',
#   'barnootaa',
#   'godina',
#   'Iluu',
#   'Abbaa',
#   'Boor',
#   'beeksiseera',
#   '.'],
#  ['Raayyaa',
#   'Barnoota',
#   'isaaniin',
#   'qo�achuun',
#   'qormaata',
#   'biyyaalessaaf',
#   'of-qopheessaa',
#   'akka',
#   'jiran',
#   'barattoonni',
#   'manneen',
#   'barnootaa',
#   'magaalaa',
#   'Bishooftuu',
#   'fi',
#   'Girjaa',
#   'himan',
#   '.'],
#  ['Yuunivarsittin',
#   'bulee',
#   'horaa',
#   'hojii',
#   'baruu',
#   'fi',
#   'barsiisuun',
#   'cinaatti',
#   'rakkoole',
#   'hawaasa',
#   'furuu',
#   'irraattis',
#   'xiyyeefate',
#   'hojechaa',
#   'jira',
#   '.',
#   'Yuunivasitichii',
#   'waajjira',
#   'horsiisee',
#   'bulaa',
#   'aanaa',
#   'Gorroo',
#   'Doolaa',
#   'waliin',
#   'ta�un',
#   'biqiltu',
#   'muka',
#   'kuma',
#   '30',
#   'naannoo',
#   'Haroo',
#   'garmaduu',
#   'dhabaan',
#   '.'],
#  ['Barattoonni',
#   'Godina',
#   'Qellem',
#   'Wallaggaa',
#   ',',
#   'Aanaa',
#   'Hawwaa',
#   'galaan',
#   ',',
#   'raayyaa',
#   'barnootaan',
#   'gurmoofnee',
#   'hojjechaa',
#   'waan',
#   'jiruuf',
#   'qabxiin',
#   'keenya',
#   'foyya�aa',
#   'jira',
#   'jedhan',
#   '.',
#   'Barattoonni',
#   'qormaata',
#   'biyyoolessaa',
#   'bara',
#   'kanarraatti',
#   'qabxii',
#   'gaarii',
#   'akka',
#   'galmeessisaniif',
#   'xiyyeeffannoon',
#   'hojjetamaa',
#   'akka',
#   'jiru',
#   'waajjirri',
#   'barnoota',
#   'godina',
#   'Qellem',
#   'wallaggaa',
#   'beeksise',
#   '.'],
#  ['Barattoonni',
#   'aanaalee',
#   'Guutoo-Giddaa',
#   'fi',
#   'Qimbibiit',
#   'qormaata',
#   'biyyaalessaa',
#   'fudhatan',
#   'qabxii',
#   'gaarii',
#   'akka',
#   'argatan',
#   'hojjetamaa',
#   'jira',
#   'jedhame.Barattoonnis',
#   'kana',
#   'milkeessuuf',
#   'sirnaan',
#   'qu�achaa',
#   'akka',
#   'jiran',
#   'himan'],
#  ['Yuunivarsiitiin',
#   'Bulee',
#   'Horaa',
#   'hojii',
#   'baruu',
#   'fi',
#   'barsiisuun',
#   'cinaatti',
#   'rakkoo',
#   'hawaasa',
#   'furuuf',
#   'xiyyeeffannoon',
#   'hojjechaa',
#   'akka',
#   'jiru',
#   'beeksise',
#   '.'],
#  ['Ejensiin',
#   'madaallii',
#   'barnootaafii',
#   'qormaataa',
#   'biyyaaleessaa',
#   'sagantaa',
#   'yeroo',
#   'qormaataa',
#   'bara',
#   '2008',
#   'baaseen',
#   'barattoonni',
#   'kutaa',
#   '10ffaafii',
#   '12ffaa',
#   'miliyoona',
#   '3',
#   'ol',
#   'Caamsaa',
#   '17irraa',
#   'eegalee',
#   'qormaata',
#   'akka',
#   'fudhatan',
#   'beeksisee',
#   'jira',
#   '.',
#   'Barattoonni',
#   'kutaa',
#   '10ffaa',
#   'Caamsaa',
#   '17-',
#   '19',
#   'Kan',
#   'qoraman',
#   'yoo',
#   'tahu',
#   'Barattoonni',
#   'kutaa',
#   '12ffaa',
#   'ammoo',
#   'Caamsaa',
#   '22',
#   'hanga',
#   '25tti',
#   'akka',
#   'qormaata',
#   'fudhataniidha',
#   'kan',
#   'hime',
#   'Yaa',
#   'ta�u',
#   'malee',
#   ',',
#   'Sababii',
#   'jeequmsa',
#   'naannoo',
#   'keenyatti',
#   'mudatee',
#   'tureen',
#   'yeroo',
#   'barnootaa',
#   'guggufate',
#   'bakka',
#   'buusuuf',
#   'sagantaan',
#   'akka',
#   'dheeratu',
#   'himee',
#   'ture',
#   '.'],
#  ['Barnoota',
#   'ga�eessotaa',
#   'gocharrati',
#   'xiyyeeffate',
#   'erga',
#   'barachuu',
#   'eegallee',
#   'barreessuu',
#   'fi',
#   'dubbisuu',
#   'cinatti',
#   'jiruu',
#   'fi',
#   'jireenya',
#   'keenya',
#   'fooyyeffachaa',
#   'jirraa',
#   'jedhan',
#   'jiraattonni',
#   'godina',
#   'shawaa',
#   'kaabaa',
#   'aanaadagama.Bara',
#   'kana',
#   'kenninsa',
#   'barnoota',
#   'gaeessotaa',
#   'karoorfame',
#   'keessaa',
#   'dhibbeentaan',
#   '70',
#   'milkaa�uu',
#   'Waajjirri',
#   'barnoota',
#   'godina',
#   'shawaa',
#   'kaabaa',
#   'beeksiseera',
#   '.'],
#  ['Barattoonni',
#   'Godina',
#   'Arsii',
#   'raayyaa',
#   'barnootaan',
#   'gurma�aii',
#   'qo�achuu',
#   'qabxiin',
#   'isanii',
#   'fayyaa',
#   'akka',
#   'jjiru',
#   'himan.Baranaa',
#   'godinichaatti',
#   'baraatoonni',
#   'kuma',
#   '26',
#   'ol',
#   'qormatta',
#   'biyyaaleessa',
#   'irratti',
#   'qabxii',
#   'garii',
#   'galmsisuu',
#   'rayyaan',
#   'gurma�anii',
#   'qo�achaa',
#   'akka',
#   'jiranui',
#   'Waajjiraa',
#   'Barnootaa',
#   'Godina',
#   'Arsii',
#   'beeksiseera',
#   '.'],
#  ['Baratoonni',
#   'kutaa',
#   '10ffaa',
#   'fi',
#   '12ffaa',
#   'Aanaa',
#   'Abbayyaa',
#   ',',
#   'qoramaata',
#   'biyyoleessaatiif',
#   'of',
#   'qopheessaa',
#   'akka',
#   'jiran',
#   'himani.Baratoota',
#   'kanneen',
#   'gama',
#   'roga',
#   'hundaan',
#   'deegaraa',
#   'akka',
#   'jiru',
#   'Waajjirri',
#   'Barnoota',
#   'Aanichaa',
#   'beeksiseera',
#   '.'],
#  ['Qormaata',
#   'biyoleessaa',
#   'irratti',
#   'qabxii',
#   'gaarii',
#   'fiduuf',
#   'raayyaan',
#   'qoachaa',
#   'akka',
#   'jiran',
#   'barattoon',
#   'qaamoolee',
#   'Daallee',
#   'Wabaraa',
#   'fi',
#   'Hawwaa',
#   'Galaan',
#   'himan.Godina',
#   'Qellem',
#   'Wallaggaatti',
#   'bara',
#   'kana',
#   'barattoonni',
#   'kuma',
#   '13',
#   'ol',
#   'qormaata',
#   'biyyolessaa',
#   'kutaa',
#   '10ffaa',
#   'fi',
#   '12ffaa',
#   'qoramuuf',
#   'qophaa�an',
#   'jiru',
#   '.'],
#  ['Barattoonni',
#   'godina',
#   'Booranaa',
#   'aanaalee',
#   'malkaa',
#   'Sooddaa',
#   'fi',
#   'Dhaasi',
#   'qormaata',
#   'biyyooleessaan',
#   'qaphxii',
#   'gaarii',
#   'galmeessuuf',
#   'raayyaan',
#   'qo�aachaa',
#   'jiru',
#   'jedhan'],
#  ['Barattoonni',
#   'Godina',
#   'Qellem',
#   'Wallaggaa',
#   ',',
#   'Aanaa',
#   'Hawwaa',
#   'galaan',
#   ',',
#   'raayyaa',
#   'barnootaan',
#   'gurmoofnee',
#   'hojjechaa',
#   'waan',
#   'jiruuf',
#   'qabxiin',
#   'keenya',
#   'foyya�aa',
#   'jira',
#   'jedhan.Barattoonni',
#   'qormaata',
#   'biyyoolessaa',
#   'bara',
#   'kanarraatti',
#   'qabxii',
#   'gaarii',
#   'akka',
#   'galmeessisaniif',
#   'xiyyeeffannoon',
#   'hojjetamaa',
#   'akka',
#   'jiru',
#   'waajjirri',
#   'barnoota',
#   'godina',
#   'Qellem',
#   'wallaggaa',
#   'beeksise',
#   '.'],
#  ['Jiraattonni',
#   'Aanaa',
#   'Aqaaqii',
#   ',',
#   'manneen',
#   'barnootaa',
#   'aanichaa',
#   'tokko',
#   'tokkotti',
#   ',',
#   'hanqinni',
#   'kitaabaa',
#   'fi',
#   'barsiisaa',
#   'akka',
#   'jiru',
#   'himan.Biiroon',
#   'Barnootaa',
#   'Oromiyaas',
#   ',',
#   'manneen',
#   'barnootaa',
#   'naannichaa',
#   'hanqina',
#   'kitaabaa',
#   'qabaniif',
#   'kitaabota',
#   'miiliyoona',
#   '13',
#   'ol',
#   'maxxansiisuuf',
#   ',',
#   'birrii',
#   'miiliyoona',
#   '300',
#   'ol',
#   'ramadee',
#   'hojjechaa',
#   'akka',
#   'jiru',
#   'beeksise.Barana',
#   'hanga',
#   'yoonaatti',
#   ',',
#   'kitaabileen',
#   'miiliyoona',
#   'torbaa',
#   'ol',
#   'maxxansiisuun',
#   'raabseera',
#   '.'],
#  ['Qormaata',
#   'biyyaleessaa',
#   'irratti',
#   'qabxii',
#   'olaanaa',
#   'galmeessisuuf',
#   'raayyaan',
#   'qo�achaa',
#   'akka',
#   'jiran',
#   'barattoonni',
#   'aanaa',
#   'Daallee',
#   'Wabaraa',
#   'fi',
#   'Hawwaa',
#   'Galaan',
#   'himan.Godina',
#   'Qellem',
#   'Wallaggaatti',
#   'bara',
#   'kana',
#   'barattoonni',
#   'kuma',
#   '13',
#   'ol',
#   'qormaata',
#   'biyyolessaa',
#   'kutaa',
#   '10ffaa',
#   'fi',
#   '12ffaa',
#   'qoramuuf',
#   'qophaa�an',
#   'jiru'],
#  ['Qorannoowwan',
#   'akkaataa',
#   'itti',
#   'fayyadama',
#   'qabeenya',
#   'uumamaa',
#   'fi',
#   'oomishtummaa',
#   'dabaluun',
#   'danda�amurratti',
#   'Yunivarsiitota',
#   'biyyattii',
#   'adda',
#   'addaatiin',
#   'qorataman',
#   'Yunivarsiitii',
#   'Wallaggaa',
#   'Kaampaasii',
#   'Shaambuutti',
#   'dhiyaachuun',
#   'irratti',
#   'mar�atame',
#   '.'],
#  ['Yuunivarsiitiin',
#   'Wolloo',
#   ',',
#   'dhaabbilee',
#   'Indaastirii',
#   'naannichatti',
#   'babal�achaa',
#   'jiran',
#   'waliin',
#   ',',
#   'walitti',
#   'hidhamiinsa',
#   'cimaa',
#   'uumuun',
#   'guddina',
#   'damee',
#   'indaastiriif',
#   'hojjechaa',
#   'akka',
#   'jiru',
#   'beeksise.Xiyyeeffannoo',
#   'qulqullina',
#   'barnootaaf',
#   'kennameenis',
#   ',',
#   'haalli',
#   'baruu',
#   'fi',
#   'barsiisuu',
#   'yuunivarsiitichaa',
#   'fooyya�aa',
#   'akka',
#   'jirus',
#   'barattoonni',
#   'himaniiru',
#   '.'],
#  ['Barnoota',
#   'qulqullina',
#   'qabu',
#   'kennuun',
#   ',',
#   'lammiilee',
#   'qaroomsuun',
#   ',',
#   'mul�ata',
#   'Ministira',
#   'Muummee',
#   'Obbo',
#   'Mallas',
#   'Zeenaawii',
#   'galmaan',
#   'ga�uuf',
#   'akka',
#   'hojjatan',
#   ',',
#   'Bakka',
#   'bu�oonni',
#   'Yunivarsiitiiwwan',
#   'gara',
#   'garaa',
#   'dubbatan',
#   '.',
#   'Bakka',
#   'bu�oonni',
#   'dhaabbilee',
#   'Barnoota',
#   'tokko',
#   'tokkoo',
#   '.'],
#  ['Dhaabbanni',
#   'Barnootaa',
#   'Leenjii',
#   'Teeknikaa',
#   'fi',
#   'Oogummaa',
#   'Dirree',
#   'Badhaasa',
#   'bara',
#   '2002',
#   'tajaajila',
#   'kan',
#   'eegalee',
#   'yoo',
#   'ta�u',
#   'hanga',
#   'ammatti',
#   'barattoota',
#   '300',
#   'eebiseera'],
#  ['Qindoomina',
#   'manneen',
#   'barnootaa',
#   'fi',
#   'yunivarsitiiwwan',
#   'gidduu',
#   'jiru',
#   'cimsuun',
#   'qulqullina',
#   'barnootaa',
#   'mirkaneessuuf',
#   'hojjetamuu',
#   'akka',
#   'qabu',
#   ',',
#   'yunivarsitiin',
#   'Finfinnee',
#   'beeksise',
#   '.',
#   'Leenjiin',
#   'dhimma',
#   'kanarratti',
#   'xiyyeeffates',
#   'ogeeyyii',
#   'barnootaa',
#   'Godina',
#   'Addaa',
#   'Oromiyaa',
#   'Naannawaa',
#   'Finfinneetiif',
#   'Bishooftutti',
#   'kennameera',
#   '.'],
#  ['Manni',
#   'Barnootaa',
#   'Naannoosaanitti',
#   'ijaaramuunsaa',
#   ',',
#   'baasii',
#   'gara',
#   'garaa',
#   'irraa',
#   'akka',
#   'isaan',
#   'baraaree',
#   'jirattoonni',
#   'magaalaa',
#   'Awwadaay',
#   'himan'],
#  ['Yuunivarsitiwwan',
#   'hojii',
#   'baru',
#   'fi',
#   'barsisu',
#   'cinaatti',
#   'qorannoowwan',
#   'rakkoolee',
#   'hawaasa',
#   'qorannoowwan',
#   'rakkoolee',
#   'hawaasa',
#   'furan',
#   'xiyyeeffatani',
#   'hojjachuun',
#   'dudhaalee',
#   'seenaa',
#   'aadaa',
#   'fi',
#   'qaromina',
#   'biyyatti',
#   'tumsu',
#   'akka',
#   'qaban',
#   'himame',
#   '.',
#   'Konfiransiin',
#   'Idil',
#   'Addunyaa',
#   'Arkiyoolojii',
#   '2ffaan',
#   'yuunivarsiti',
#   'Addigraatitti',
#   'bu�aa',
#   'qoraannoo',
#   'arkiyoolojii',
#   'qorattoota',
#   'biyyaa',
#   'keessa',
#   'fi',
#   'alan',
#   'argame',
#   'dhiyaateera',
#   '.'],
#  ['Barnoota',
#   'qulqullina',
#   'qabu',
#   'kennuun',
#   'lammii',
#   'guddina',
#   'biyyaa',
#   'keessaatti',
#   'gahee',
#   'isaa',
#   'gumaachu',
#   'horachuuf',
#   'ni',
#   'hojjenna',
#   'jedhan',
#   'barsiisonni',
#   'manneen',
#   'barnootaa',
#   'Magaalota',
#   'Duukam',
#   'Hoolataa',
#   'fi',
#   'Aanaa',
#   'sulultaa',
#   '.',
#   'Leenjiin',
#   'barsiisota',
#   'kanneenniif',
#   'paakeejii',
#   'mirkaneeffannaa',
#   'qulqullina',
#   'barnootaa',
#   'irraatti',
#   'kennamaa',
#   'ture',
#   'xumurameera'],
#  ['Jiraattonni',
#   'godina',
#   'Horroo',
#   'Guduruu',
#   'Wallaggaa',
#   'aanaa',
#   'Haabaaboo',
#   'Guduruu',
#   ',',
#   'mana',
#   'barumsa',
#   'sadarkaa',
#   '2ffaa',
#   'hojjetamuu',
#   'isaatiin',
#   'fayyadamtoota',
#   'taaneraa',
#   '.',
#   'Pirojektiin',
#   'mana',
#   'barumsa',
#   'sadarkaa',
#   'Qawoo',
#   'bajata',
#   'motummaa',
#   'fi',
#   'hirmaannaa',
#   'ummata',
#   'birri',
#   'miiliyoona',
#   '8.3',
#   'hojatame'],
#  ['Jiraattonni',
#   'Godina',
#   'Arsii',
#   'Magaalaa',
#   'Hurutaa',
#   'daa�immaan',
#   'umuriin',
#   'isaani',
#   'barnootaaf',
#   'gahan',
#   'galmeessisaa',
#   'akka',
#   'jiran',
#   'himan',
#   '.',
#   'Godinchaatti',
#   'daa�immaan',
#   'umuriin',
#   'isaanii',
#   'barnootaaf',
#   'gahan',
#   'hundi',
#   ',',
#   'mana',
#   'barnootaa',
#   'akka',
#   'galaniif',
#   'xiyyeeffannaan',
#   'hojjatamaa',
#   'akka',
#   'jiru',
#   'Waajjirri',
#   'Barnoota',
#   'godinichaa',
#   'beeksiseera',
#   '.'],
#  ['Jiraattonni',
#   'Godina',
#   'Arsii',
#   'Magaalaa',
#   'Hurutaa',
#   'daa�immaan',
#   'umuriin',
#   'isaani',
#   'barnootaaf',
#   'gahan',
#   'galmeessisaa',
#   'akka',
#   'jiran',
#   'himan.Godinchaatti',
#   'daa�immaan',
#   'umuriin',
#   'isaanii',
#   'barnootaaf',
#   'gahan',
#   'hundi',
#   ',',
#   'mana',
#   'barnootaa',
#   'akka',
#   'galaniif',
#   'xiyyeeffannaan',
#   'hojjatamaa',
#   'akka',
#   'jiru',
#   'Waajjirri',
#   'Barnoota',
#   'godinichaa',
#   'beeksiseera',
#   '.'],
#  ['Oromiyaa',
#   'keessatti',
#   'mannen',
#   'barnoota',
#   'sadarkaa',
#   '1ffaa',
#   'hanga',
#   'qophaa�inaatti',
#   ',',
#   'barattoonni',
#   'miiliyoona',
#   '7',
#   'fi',
#   'kuma',
#   '700',
#   'horatamuu',
#   ',',
#   'bareeffamni',
#   'haala',
#   'yeroo',
#   'irratti',
#   'ejjennoo',
#   'mootummaa',
#   'balballoomsu',
#   'eereera',
#   '.',
#   'Barattoota',
#   'sadarkaa',
#   'hundatti',
#   'argamaniif',
#   ',',
#   'Fulbaana',
#   '10',
#   'hanga',
#   '15tti',
#   ',',
#   'leenjiin',
#   'qulqullina',
#   'barnootaa',
#   'mirkanneessuu',
#   'irratti',
#   'xiyyeeffate',
#   'akka',
#   'kennamu',
#   ',',
#   'ibsi',
#   'biiroon',
#   'dhimmoota',
#   'kominikeeshinii',
#   'mootummaa',
#   'naannoo',
#   'Oromiyaa',
#   'nuun',
#   'gahe',
#   'mul�iseera',
#   '.'],
#  ['Manni',
#   'Barumsaa',
#   'Addaa',
#   'Waldaan',
#   'Misooma',
#   'Oromiyaa',
#   'godina',
#   'Shawaa',
#   'Lixaa',
#   'aanaa',
#   'Tokkee',
#   'Kuttaayee',
#   'Magaalaa',
#   'Gudaritti',
#   'ijaarsise',
#   'eebbifame',
#   '.',
#   'Barreessaa',
#   'Olaanaan',
#   'Dhaabbata',
#   'Biyyoota',
#   'Gamtoomanii',
#   'Baan',
#   'kimuun',
#   ',',
#   'Qondaaltonni',
#   'mootummaa',
#   'imaammata',
#   'jijjiirama',
#   'qilleensaa',
#   'milkaa�aa',
#   'akka',
#   'baasan',
#   'waamicha',
#   'dhiheessan'],
#  ['Muuxannoo',
#   'mana',
#   'fincaaniitti',
#   'sirnaan',
#   'fayyadamaa',
#   'jiruu',
#   'babaldhisuun',
#   'gandoota',
#   'baadiyyaa',
#   'godina',
#   'arsii',
#   'lixaa',
#   'hunda',
#   'bobbaa',
#   'dirree',
#   'irraa',
#   'bilsa',
#   'gochuuf',
#   'xiyyeefannoon',
#   'hojjatamaa',
#   'kan',
#   'jiru',
#   "ta'uu",
#   'isaa',
#   'waajjirri',
#   'fayyaa',
#   'Godina',
#   'arsii',
#   'lixaa',
#   'beeksiseera',
#   'Hojjattoota',
#   'ekisteenshinii',
#   'fayyaa',
#   'hojii',
#   'bobbaa',
#   'dirreexiqqeessuuf',
#   'hojjatamaa',
#   'jiru',
#   'keessatti',
#   ',',
#   'adda',
#   'durummaan',
#   "ga'ee",
#   'isaanii',
#   'gumaachaa',
#   'jiraniif',
#   'badhaasni',
#   'haamilee',
#   'isaanii',
#   'cimsu',
#   'kennameera',
#   '.'],
#  ['Yuunivarsiitiin',
#   'Jimmaa',
#   'Barattoota',
#   'haara',
#   'kuma',
#   '5',
#   'fi',
#   '200',
#   'barana',
#   'simateef',
#   'leenjii',
#   'haala',
#   'qabatamaa',
#   'biyyaa',
#   'fi',
#   'galmoota',
#   'ijoo',
#   'karoora',
#   'guddinaa',
#   'fi',
#   'jijjiirama',
#   'bu�uuraa',
#   'irratti',
#   'xiyyeeffate',
#   'kenne',
#   '.'],
#  ['Paakeejiiwwan',
#   'qulqullina',
#   'barnootaa',
#   'mirkaneessuuf',
#   ',',
#   'leenjiin',
#   'kennamaafii',
#   'ture',
#   ',',
#   'hubannoo',
#   'gahaa',
#   'kan',
#   'uumeef',
#   'ta�uu',
#   'baratoonni',
#   'Yuunivesiitii',
#   'Arsii',
#   'himan',
#   '.'],
#  ['Biiroon',
#   'Barnootaa',
#   'Oromiyaa',
#   'Abbootiin',
#   'adeemsa',
#   'hojii',
#   'baruu',
#   'fi',
#   'barsiisuu',
#   'manneen',
#   'barnootaa',
#   'fi',
#   'barsiisonni',
#   'saayinsii',
#   'afaanii',
#   'hanqina',
#   'dandeettii',
#   'dubbisuu',
#   'fi',
#   'barreessuu',
#   'barattoota',
#   'biratti',
#   'bal�inaan',
#   'mul�atan',
#   'furuuf',
#   ',',
#   'xiyyeeffannoon',
#   'hojjechuu',
#   'akka',
#   'qaban',
#   'hubachiise.Leenjiin',
#   'dhimma',
#   'kana',
#   'irratti',
#   'xiyyeeffate',
#   'itti',
#   'gaafatamtoota',
#   'seektara',
#   'barnootaaf',
#   'Adaamaatti',
#   'kennameera',
#   '.'],
#  ['Jiraatotni',
#   'Godina',
#   'Wallaggaa',
#   'Lixaa',
#   'Aanaa',
#   'Laaloo',
#   'Assaabi',
#   'dhimma',
#   'barnoota',
#   'irratti',
#   'hirmaachuu',
#   'erga',
#   'eegalee',
#   'manneen',
#   'barnootaa',
#   'babbal�atee',
#   'ijoolleen',
#   'keenya',
#   'dhiheenyatti',
#   'nuuf',
#   'barachuun',
#   'harcaatii',
#   'baratootaa',
#   'hanbisaa',
#   'jira',
#   'jedhan.Waajirri',
#   'barnootaa',
#   'Godinichaas',
#   'manneen',
#   'barnootaa',
#   'babbal�ataa',
#   'jiran',
#   'keessatti',
#   'barnoonni',
#   'qulqullina',
#   'qabu',
#   'akka',
#   'kennamuuf',
#   'hojjetaa',
#   'jiraachuu',
#   'beeksiseera',
#   '.'],
#  ['Barattoonni',
#   'Yuunivarsiitiiwwan',
#   'Jimmaa',
#   'fi',
#   'Wallaggaatti',
#   'Imaammata',
#   'fi',
#   'Tarsiimoo',
#   'Mootummaa',
#   'Misoomawaa',
#   'irratti',
#   'Leenji�aa',
#   'jiran',
#   ',',
#   'Leenjicha',
#   'irraa',
#   'hubannoon',
#   'argatan',
#   'ilaalcha',
#   'biyyaalessummaa',
#   'horachuun',
#   'guddina',
#   'biyyaaf',
#   'akka',
#   'tumsaniif',
#   'kan',
#   'isaan',
#   'gargaaru',
#   'ta�uu',
#   'himan',
#   '.'],
#  ['Godina',
#   'Addaa',
#   'Oromiyaa',
#   'Bulchiinsa',
#   'Magaalaa',
#   'Sulultaatti',
#   'barsiistonni',
#   'Leenjii',
#   'Imaammata',
#   'biyyaa',
#   'irratti',
#   'fudhatan',
#   'leenjichi',
#   'qulqullina',
#   'barnootaa',
#   'mirkaneessun',
#   'lammii',
#   'biyyaaf',
#   'yaadu',
#   'horachuuf',
#   'nu',
#   'gargaarera',
#   'jedhanBarsiistonni',
#   'Magaalaa',
#   'sulultaa',
#   'tarsiimoo',
#   'imaammata',
#   'biyyaa',
#   'irraatti',
#   'leenjii',
#   'fudhachaa',
#   'jiru',
#   '.',
#   'Gabaasa',
#   'waajjira',
#   'dhimmoota',
#   'kominikeeshinii',
#   'mootummaa',
#   'bulchiinsa',
#   'Magaalaa',
#   'Sulultaaf',
#   'Caalaa',
#   'Barakaa',
#   '.'],
#  ['Bulchiinsa',
#   'Magaalaa',
#   'Naqamtee',
#   'fi',
#   'Godina',
#   'Baaletti',
#   'Barsiisotaa',
#   'Manneen',
#   'Barnootaa',
#   'Sadarkaa',
#   '2ffaa',
#   'fi',
#   'Kolleejjotaa',
#   'Barsiisaniif',
#   'Leenjiin',
#   'Imaammataa',
#   'fi',
#   'Tarsiimoo',
#   'Mootummaa',
#   'Misoomawaarratti',
#   'kennamaa',
#   'jira.Barsiisoonni',
#   'leenjii',
#   'kana',
#   'fudhachaa',
#   'jiranis',
#   ',',
#   'qulqullina',
#   'barnootaan',
#   'mirkaneessuun',
#   'haaromsa',
#   'biyyaa',
#   'dhugoomsuuf',
#   'akka',
#   'hojjatan',
#   'himaniiru',
#   '.'],
#  ['Bulchiinsa',
#   'Magaalaa',
#   'Naqamtee',
#   'fi',
#   'Godina',
#   'Baaletti',
#   'Barsiisotaa',
#   'Manneen',
#   'Barnootaa',
#   'Sadarkaa',
#   '2ffaa',
#   'fi',
#   'Kolleejjotaa',
#   'Barsiisaniif',
#   'Leenjiin',
#   'Imaammataa',
#   'fi',
#   'Tarsiimoo',
#   'Mootummaa',
#   'Misoomawaarratti',
#   'kennamaa',
#   'jira.Barsiisoonni',
#   'leenjii',
#   'kana',
#   'fudhachaa',
#   'jiranis',
#   ',',
#   'qulqullina',
#   'barnootaan',
#   'mirkaneessuun',
#   'haaromsa',
#   'biyyaa',
#   'dhugoomsuuf',
#   'akka',
#   'hojjatan',
#   'himaniiru'],
#  ['Ministirri',
#   'Dhimma',
#   'Alaa',
#   'Ameerikaa',
#   'Joon',
#   'keeriin',
#   'kan',
#   'Gamtaa',
#   'Awurooppaa',
#   'Kaateriin',
#   'Ashtan',
#   'waliin',
#   'barbaachisummaa',
#   'fi',
#   'milkaa�ina',
#   'yaa�ichaa',
#   'irratti',
#   'mar�ataniiru.Ministirri',
#   'Dhimma',
#   'Alaa',
#   'Raashiyaas',
#   'gita',
#   'isaanii',
#   'kan',
#   'Yuukireen',
#   'waliin',
#   'mari�achuufI.Mariin',
#   'Raashiyaa',
#   'fi',
#   'yuukireen',
#   'gidduutti',
#   'taa�amu',
#   'walii',
#   'galteerra',
#   'ga�aamuunsaa',
#   'shakkii',
#   'keessa',
#   'jira',
#   ',',
#   'sababni',
#   'isaas',
#   'Raashiyaan',
#   'Mootummaa',
#   'Ce�umsaa',
#   'Yuukireenitti',
#   'hin',
#   'amanne',
#   'waan',
#   'ta�eef',
#   'falmii',
#   'cimaa',
#   'kaasuu',
#   'danda�a',
#   'jedhameera.Ameerikaan',
#   'gama',
#   'isheetiin',
#   'Raashiyaan',
#   'marii',
#   'Jeenevaaf',
#   'hudhaa',
#   'yoo',
#   'taate',
#   'qoqqobbii',
#   'dabalataa',
#   'irra',
#   'kaa�uuf',
#   'qophaa�eera',
#   'jetti',
#   '.'],
#  ['Barattoonni',
#   'qormaata',
#   'kutaa',
#   '12ffaa',
#   'fudhatan',
#   'namoota',
#   'deebii',
#   'sobaa',
#   'tamsaasan',
#   'irraa',
#   'akka',
#   'of',
#   'eegan',
#   ',',
#   'Biiroon',
#   'Barnootaa',
#   'Oromiyaa',
#   'beeksise.Hoogganaan',
#   'Biiroon',
#   'Barnootaa',
#   'Oromiyaa',
#   'Obbo',
#   'Margaa',
#   'Fayyisaa',
#   ',',
#   'qormaaticha',
#   'milkeessuu',
#   'keessatti',
#   'qaamoleen',
#   'barnootaa',
#   'fi',
#   'nageenyaa',
#   'gahee',
#   'irraa',
#   'eegamu',
#   'akka',
#   'bahan',
#   'hubachiisan',
#   '.',
#   'Qormaanni',
#   'kutaa',
#   '12ffaa',
#   'har�a',
#   'irraa',
#   'eegale',
#   'guutuu',
#   'biyyaatti',
#   'ni',
#   'kennama',
#   '.'],
#  ['Barmaatilee',
#   'dubatti',
#   'hafoo',
#   'hirmaannaa',
#   'hawaasan',
#   'maqsuun',
#   ',',
#   'harcaatii',
#   'barattoota',
#   'shamarrani',
#   'manneen',
#   'barnootaa',
#   'keessatti',
#   'xiqqeessun',
#   'akka',
#   'danda�ame',
#   'Biiroon',
#   'Barnoota',
#   'Oromiyaa',
#   'beeksise.Fooramiin',
#   'barattoota',
#   'dubaraa',
#   '10ffaan',
#   'qooda',
#   'fudhattoota',
#   'waliin',
#   'Magaalaa',
#   'Adaamaatti',
#   'taa�ame',
#   '.'],
#  ['Qophiin',
#   'Qormaata',
#   'biyyaaleessaa',
#   'kutaa',
#   '10ffaa',
#   'fi',
#   '12ffaa',
#   'xumuramee',
#   ',',
#   'qormaanni',
#   'gara',
#   'buufatawwan',
#   'qormaataatti',
#   'raabsamuu',
#   'akka',
#   'eegale',
#   'Ejensiin',
#   'Madaallii',
#   'Barnootaa',
#   'fi',
#   'Qormaatawwanii',
#   'Biyyaaleessaa',
#   'beeksise',
#   '.',
#   'Qormaata',
#   'kutaa',
#   '10ffaa',
#   'baranaa',
#   'barattoonni',
#   'Miiliyoona',
#   'tokko',
#   'caalaan',
#   ',',
#   'kan',
#   'kutaa',
#   '12ffaa',
#   'immoo',
#   'baratoonni',
#   'kuma',
#   '200',
#   'fi',
#   'kuma',
#   '53',
#   'akka',
#   'qoraman',
#   'Ejensichi',
#   'beeksiseera',
#   '.'],
#  ['Barattoonni',
#   'manneen',
#   'barnoota',
#   'Aanaa',
#   'Jaarsoo',
#   'qormaata',
#   'biyyaleessaaf',
#   'tokko',
#   'shaneen',
#   "qo'achuun",
#   'of',
#   'qopheessaa',
#   'jiraachuu',
#   'himan.Godina',
#   'Wallagga',
#   'Lixaatti',
#   'barattoota',
#   'kuma',
#   '500',
#   'ol',
#   'raayyaan',
#   "gurma'eessuun",
#   'deeggaraa',
#   'jiraachuu',
#   'Waajjirri',
#   'Barnoota',
#   'Godinichaas',
#   'beeksisera',
#   '.'],
#  ['Ilaalcha',
#   'hirkattummaa',
#   'hambisuu',
#   'fi',
#   'nageenya',
#   'mirkaneessuun',
#   'qormaata',
#   'biyyoolessaa',
#   'baranaa',
#   'karaa',
#   'milkaa�een',
#   'raawwachuuf',
#   'qophiin',
#   'barbaachisu',
#   'taasifamaa',
#   'jiraachuu',
#   'Biiroon',
#   'Barnootaa',
#   'Oromiyaa',
#   'beeksise.Biirichi',
#   'akkaataa',
#   'qormaata',
#   'baranaa',
#   'karaa',
#   'nagaan',
#   'raawwachuun',
#   'danda�amuu',
#   'irratti',
#   'qooda',
#   'fudhattoota',
#   'waliin',
#   'mari�ateera',
#   '.'],
#  ['Barattoonnii',
#   'fi',
#   'maatiin',
#   'barattootaa',
#   'Godinaalee',
#   'Harargee',
#   'Lixaa',
#   'fi',
#   'Shawaa',
#   'Kaabaa',
#   'Qormaata',
#   'biyyaalessaa',
#   'kutaa',
#   '12ffaa',
#   'irratti',
#   'badii',
#   'gaheen',
#   'murtii',
#   'mootummaan',
#   'murteesse',
#   'sirrii',
#   'ta�uu',
#   'dubbatan',
#   '.',
#   'Fuula',
#   'duraafis',
#   'rakkoon',
#   'kun',
#   'akka',
#   'hin',
#   'mudanne',
#   'xiyyeeffannoon',
#   'barbaachisaan',
#   'taasifamu',
#   'akka',
#   'qabu',
#   'dhaaman.Yaada',
#   'jiraattota',
#   'kanneenii',
#   'Mohaammad',
#   'Usmaanii',
#   'fi',
#   'Gaarii',
#   'Lammaa',
#   'nuuf',
#   'ergan',
#   ',',
#   'Lalii',
#   'Girmaatu',
#   'qindeessite',
#   '.'],
#  ['Barattoonni',
#   'Oromiyaa',
#   'qormaata',
#   'Naannoo',
#   'fi',
#   'biyyaalessaa',
#   'irraatti',
#   'qabxii',
#   'gaarii',
#   'akka',
#   'galmeessanii',
#   'fi',
#   'dorgomtoota',
#   'akka',
#   'ta�aniif',
#   ',',
#   'adeemsi',
#   'kenniinsa',
#   'qormaataa',
#   'karaa',
#   'nagaa',
#   'fi',
#   'tasgabbii',
#   'qabuun',
#   'akka',
#   'raawwatuuf',
#   'qaamni',
#   'hundi',
#   'gahee',
#   'isaa',
#   'bahuu',
#   'qabaa',
#   'jedhan',
#   ',',
#   'Hoogganaan',
#   'Biiroo',
#   'Barnootaa',
#   'Oromiyaa',
#   'Obboo',
#   'Margaa',
#   'Fayyisaa',
#   '.'],
#  ['Raayyaa',
#   'barnootaan',
#   'gurmoofnee',
#   'qo�achuun',
#   'qormaata',
#   'biyyaaleessaa',
#   'irratti',
#   'qabxii',
#   'gaarii',
#   'galmesisuuf',
#   'hojjechaa',
#   'jirraa',
#   'jedhan',
#   'Aannaa',
#   'galaanaatti',
#   'barattoonni',
#   'manneen',
#   'barnoota',
#   'sadarkaa',
#   '2ffaa',
#   'fi',
#   'qophaa�inaa',
#   '.'],
#  ['Qulqullina',
#   'barnootaa',
#   'caalaatti',
#   'mirkaneessuun',
#   'haaromsa',
#   'biyyaa',
#   'milkeessuuf',
#   'hojjetamaa',
#   'akka',
#   'jiru',
#   ',',
#   'Af-Yaa�iin',
#   'Mana',
#   'Maree',
#   'bakka',
#   'bu�oota',
#   'Uummataa',
#   'Obbo',
#   'Abbaa',
#   'Duulaa',
#   'Gammadaa',
#   'himan.Waldaan',
#   'Misoomaa',
#   'Oromiyaa',
#   ',',
#   'Mana',
#   'Barumsaa',
#   'adda',
#   'godina',
#   'Shawa',
#   'Lixaa',
#   'Aanaa',
#   'Tokkee',
#   'Kuttaayeetti',
#   'ijaaruuf',
#   'dhakkaa',
#   'bu�uuraa',
#   'kaa�eera',
#   '.'],
#  ['Qoranoowwan',
#   'rakkoo',
#   'hawaasaa',
#   'hiiku',
#   'danda�aanii',
#   'fi',
#   'barnoota',
#   'hawaasa',
#   'bu�uureffate',
#   'walitti',
#   'qindeessuun',
#   'dhaabbile',
#   'barnootaa',
#   'olaanoo',
#   'hunda',
#   'keessatti',
#   'hojii',
#   'irra',
#   'oolchuuf',
#   'hojjatamaa',
#   'akka',
#   'jiru',
#   'ministirri',
#   'barnootaa',
#   'Obbo',
#   'Shifarraawu',
#   'Shigguxee',
#   'himan.Muuxannoo',
#   'Yuniivarsiitiin',
#   'Jimmaa',
#   'woggoottan',
#   '30',
#   'darban',
#   'keessatti',
#   'gama',
#   'barnoota',
#   'hawaasa',
#   'bu�uureffate',
#   ',',
#   'hojii',
#   'irraa',
#   'oolchuutiin',
#   'horatee',
#   'fi',
#   'bu�aa',
#   'argamsiise',
#   'haala',
#   'baballisuu',
#   'danda�amu',
#   'irratti',
#   'yuuniivarsiitichatti',
#   'mariin',
#   'taa�ameera',
#   '.'],
#  ['Barnoota',
#   'qulqullina',
#   'qabu',
#   'lammii',
#   'hundaan',
#   'gahuun',
#   'imala',
#   'guddina',
#   'misoomaa',
#   'biyyiittin',
#   'eegalte',
#   'humna',
#   'barateen',
#   'mirkaneessuuf',
#   'barsiisonni',
#   'gahee',
#   'isaanii',
#   'gumaachuu',
#   'akka',
#   'qaban',
#   'Biiroon',
#   'Barnoota',
#   'Oromiyaa',
#   'hubachiise.Koolleejjiin',
#   'barnoota',
#   'barsiisota',
#   'Naqamtee',
#   'marsaa',
#   '13ffaan',
#   'barsiisota',
#   '833',
#   'dippiloomaa',
#   'fi',
#   'sertifikeetaan',
#   'eebbise',
#   '.'],
#  ['Barattoonni',
#   'dhaabbilee',
#   'barnootaa',
#   'olaanoo',
#   'irraa',
#   'eebbifamuun',
#   'karooraa',
#   'addaan',
#   'akka',
#   'hojiitti',
#   'galaniif',
#   'haalli',
#   'mijateef',
#   'deeggarsa',
#   'argataniin',
#   'humnaa',
#   'fi',
#   'beekumsaa',
#   'qaban',
#   'qindeessuun',
#   'hiyyummaa',
#   'injifachuuf',
#   'qophii',
#   'ta�uu',
#   'himan.-Barattoonni',
#   'dhaabbilee',
#   'barnootaa',
#   'olaannoo',
#   'irraa',
#   'eebbifaman',
#   'karoora',
#   'addaaan',
#   'hojiitti',
#   'akka',
#   'galaniif',
#   'karoorfame',
#   'keessaa',
#   'kanneen',
#   '259',
#   'ta�an',
#   'akkaataa',
#   'milkaa�uu',
#   'danda�an',
#   'irratti',
#   'Koolleejjii',
#   'Qonnaa',
#   'Ardaa�itaatti',
#   'hojii',
#   'qonnaa',
#   'irratti',
#   'leenji�aniiiru',
#   '.'],
#  ['Qorumsa',
#   'biyyooleessaa',
#   'milkaa�uuf',
#   'of-qopheessaa',
#   'akka',
#   'jiran',
#   'barattoonni',
#   'mana',
#   'barumsaa',
#   'sadarkaa',
#   '2ffaa',
#   'Sabbataa',
#   'fi',
#   'qophaa�ina',
#   'sabbataa',
#   'ibsan.Barana',
#   'naannoo',
#   'Oromiyaatti',
#   'barattoonni',
#   'kutaa',
#   '8ffaa,10ffaa',
#   'fi',
#   '12ffaa',
#   'kuma',
#   '900',
#   'ol',
#   'qormaata',
#   'naannoo',
#   'fi',
#   'biyyaaleessaa',
#   'kan',
#   'qoraman',
#   'ta�uu',
#   'Biiroon',
#   'Barnootaa',
#   'Oromiyaa',
#   'beeksise',
#   '.'],
#  ['Godina',
#   'Wallaggaa',
#   'Lixaatti',
#   'Barattoonni',
#   'Mana',
#   'Barumsaa',
#   'sadarkaa',
#   'lammaffaa',
#   'Gimbii',
#   'qormaata',
#   'biyyoolessaatti',
#   'qabxiii',
#   'gaarii',
#   'argachuuf',
#   'cimanii',
#   'hojjechaa',
#   'akka',
#   'jiran',
#   'himan',
#   '.'],
#  ['Waajjirri',
#   'Barnoota',
#   'Aanaa',
#   'Warraa',
#   'Jarsoo',
#   ',',
#   'hojii',
#   'baruu',
#   'fi',
#   'barsiisuu',
#   'baranaa',
#   'milkeesuuf',
#   ',',
#   'qooda',
#   'fudhatoota',
#   'waliin',
#   'hojjechaa',
#   'akka',
#   'jiru',
#   'beeksise',
#   '.'],
#  ['Dureeyyiin',
#   'misooma',
#   'barnootaarratti',
#   'xiyyeeffanaan',
#   'hojjechuu',
#   'akka',
#   'qaban',
#   ',',
#   'Biiroon',
#   'Barnootaa',
#   'Oromiyaa',
#   'waamicha',
#   'dhiyeesse.Manni',
#   'Barnoota',
#   'dureessaa',
#   'tokkoon',
#   'Magaalaa',
#   'Qooqaa',
#   'Ejersaatti',
#   'ijaarame',
#   'eebbifamee',
#   'tajaajilaaf',
#   'qophaa�e',
#   '.'],
#  ['Sirni',
#   'baruuf',
#   'barsiisuu',
#   'Yuunivarsiitiiwwan',
#   'muraasa',
#   'keessatti',
#   'dhaabbatee',
#   'ture',
#   'eegaluusaa',
#   'Ministeerri',
#   'Saayinsiif',
#   'Dhaabbilee',
#   'Barnoota',
#   'Olaanoo',
#   'beeksise',
#   '.',
#   'Ministeerrichi',
#   'haala',
#   'yeroorratti',
#   'miidiyaaf',
#   'ibsa',
#   'kenne',
#   '.'],
#  ['Hanqinoota',
#   'sirna',
#   'Barnootaa',
#   'keessatti',
#   'mudatan',
#   'furuuf',
#   'ciminaan',
#   'hojjetamuu',
#   'qaba',
#   'jedhan',
# ...
#   'Ijiypti',
#   'Abdulfataa',
#   'Al-Sisi',
#   'wal',
#   'gahii',
#   'hatatamaa',
#   'qaamolee',
#   'nageenyaa',
#   'waamuun',
#   'namoota',
#   'miidhaa',
#   'qaqqabsiisan',
#   'to�annoo',
#   'seera',
#   'jala',
#   'akka',
#   'oolchan',
#   'ajaja',
#   'dabarsaniiru',
#   '.',
#   'Hawaasni',
#   'idila',
#   'adduunyaa',
#   'gocha',
#   'shoroorkeessummaa',
#   'lammilee',
#   'Ijiptii',
#   'irra',
#   'gahee',
#   'balaleefachaa',
#   'jiru.BBC',
#   'tu',
#   'gabaase',
#   '.'],
#  ['Dhaabbileen',
#   'mootummaa',
#   'naannoo',
#   'Oromiyaa',
#   '14',
#   'lammiilee',
#   'hongeen',
#   'miidhaman',
#   'gargaaruuf',
#   'waadaa',
#   'galan',
#   'raawwachuu',
#   ',',
#   'komishiniin',
#   'hooggansa',
#   'sodaa',
#   'Balaa',
#   'Oromiyaa',
#   'beeksise.Komishinichi',
#   'deeggarsi',
#   'taasifamaa',
#   'jiru',
#   'qaama',
#   'dhimmi',
#   'ilaallatu',
#   'bira',
#   'akka',
#   'qaqqabuuf',
#   'hordoffii',
#   'cimaan',
#   'taasifamaa',
#   'jiraachuus',
#   'beeksiseera',
#   '.'],
#  ['Balaa',
#   'Tiraafikaan',
#   'lubbuu',
#   'lammiilee',
#   'darbaa',
#   'jiruuf',
#   'harki',
#   '85',
#   'ol',
#   'rakkoo',
#   'konkolaachiftootaati',
#   'jedhama',
#   '.',
#   'Rakkoo',
#   'kana',
#   'hir�isuuf',
#   'dhaabbileen',
#   'leenjiftoota',
#   'konkolaachiftootaa',
#   'Finfinneetti',
#   'mari�atan',
#   '.'],
#  ['Jiraattonni',
#   'magaalaa',
#   'Bishooftuu',
#   'fi',
#   'aanaa',
#   'Gimbichuu',
#   'jiraattota',
#   'aanaa',
#   'Adaamaa',
#   'sababa',
#   'hongeen',
#   'rakkoof',
#   'saaxilamaniif',
#   'midhaan',
#   'kuntaalaa',
#   'kuma',
#   'tokko',
#   'fi',
#   'dhibbaa',
#   'shan',
#   'fi',
#   'nyaata',
#   'beeyladaa',
#   'gumaachan.Namoonni',
#   'deeggarsa',
#   'argatanis',
#   'yeroo',
#   'rakkootti',
#   'lammiin',
#   'isaanii',
#   'birmachuufiitti',
#   'gammadu',
#   'himan'],
#  ['Ameerikaatti',
#   'New',
#   'Yorkitti',
#   'konkolaachisaa',
#   'nama',
#   'tokko',
#   'ajjesee',
#   ',',
#   'namoota',
#   '22',
#   'madeese',
#   ',',
#   'to�annoo',
#   'jala',
#   'oole.Richard',
#   'Rojas',
#   'qoricha',
#   'sammuu',
#   'namaa',
#   'addochuu',
#   'fayyadamuu',
#   'fi',
#   'dhugee',
#   'konkolaachisuun',
#   'yeroo',
#   'gara',
#   'garaatti',
#   'to�annoo',
#   'seeraa',
#   'jala',
#   'ooleera.Ammas',
#   'akkuma',
#   'amala',
#   'isaa',
#   'dhugee',
#   'daandii',
#   'New',
#   'York',
#   'kan',
#   'tuuristoonni',
#   'fi',
#   'namootni',
#   'hedduun',
#   'irra',
#   'bashananaa',
#   'irraa',
#   'saffisaan',
#   'konkolaachisuun',
#   'dubara',
#   'umrii',
#   '18',
#   'tokko',
#   'ajjeessun',
#   'namoota',
#   '22',
#   'madeeseera',
#   '.',
#   'Nagaa',
#   'eegdota',
#   'Ameerikaa',
#   'balaa',
#   'qaqqabee',
#   'irratti',
#   'qorannoo',
#   'taasisaniin',
#   ',',
#   'rakkoon',
#   'uumame',
#   'balaa',
#   'shoroorkeessummaa',
#   'waliin',
#   'hariiroo',
#   'akka',
#   'qabu',
#   'beeksisaniiru',
#   'jechun',
#   'BBCni',
#   'gabaaseera',
#   '.'],
#  ['Qaamoleen',
#   'hawaasa',
#   'garaa',
#   'garaa',
#   'Godina',
#   'Arsii',
#   'lixaa',
#   'Horsiisee',
#   'Bultoota',
#   'Godina',
#   'Gujii',
#   'hongeen',
#   'miidhamaniif',
#   'midhaan',
#   'nyaataa',
#   'Kuntaala',
#   'kuma',
#   '1',
#   'fi',
#   '531',
#   'deggersaan',
#   'gumachaaniifHorsiisee',
#   'bultoonnis',
#   'deggersa',
#   'argatan',
#   'kanatti',
#   'kan',
#   'gammadan',
#   'ta�uu',
#   'isaanii',
#   'dubbataniiru',
#   '.'],
#  ['Godina',
#   'Gujii',
#   'aanaa',
#   'horsiisee',
#   'bulaa',
#   'Liibanitti',
#   'midhaan',
#   'lafa',
#   'heektara',
#   'kumaa',
#   '22',
#   'irratti',
#   'facaasan',
#   'hongee',
#   'mudateen',
#   'faayidaa',
#   'ala',
#   'ta�uu',
#   'himame.Ummanni',
#   'akka',
#   'hin',
#   'miidhamneef',
#   'xiyyeeffannoon',
#   'hojjechaa',
#   'akka',
#   'jiru',
#   'komishiniin',
#   'hoggansa',
#   'soda',
#   'balaa',
#   'Oromiyaa',
#   'beeksise',
#   '.'],
#  ['Jiraattoonni',
#   'magaalaa',
#   'Asallaa',
#   'jiraattoota',
#   'Aanaa',
#   'martii',
#   'hanqina',
#   'roobaatiin',
#   'miidhamaniif',
#   'midhaan',
#   'kuntaala',
#   '700',
#   'kennan.Haluma',
#   'walfakkaatuun',
#   'jiraattoonni',
#   'Aanaa',
#   'Luumee',
#   'fi',
#   'Ada�aas',
#   'jiraattota',
#   'Aanaa',
#   'Adaamaa',
#   'fi',
#   'Boosat',
#   'hongeen',
#   'midhamaniif',
#   'midhaan',
#   'kuntaala',
#   '900',
#   'deeggarsa',
#   'godhan',
#   '.'],
#  ['Yuuniyeenotni',
#   'gara',
#   'garaa',
#   'godina',
#   'Wallaggaa',
#   'Lixaa',
#   'horsiise',
#   'bultootta',
#   'godina',
#   'Gujii',
#   'hongeen',
#   'miidhamaniig',
#   'Boqoolloo',
#   'kuntaala',
#   '300',
#   'deeggarsaan',
#   'gumaachan.Horsiise',
#   'bultoonnis',
#   'deeggarsa',
#   'argatan',
#   'kanatti',
#   'gammadu',
#   'himan',
#   '.'],
#  ['Jiraattonni',
#   'godina',
#   'Jimmaa',
#   ',',
#   'lammiilee',
#   'godina',
#   'Harargee',
#   'Lixaa',
#   'sababa',
#   'hongeetiin',
#   'beelaaf',
#   'saaxilamaniif',
#   'deeggarsa',
#   'taasiisan.Gabaasa',
#   'waajjira',
#   'dhimmoota',
#   'kominikeeshinii',
#   'godina',
#   'Jimmaa',
#   ',',
#   'Balaachoo',
#   'Jabeesaatu',
#   'qindeesse'],
#  ['Balaa',
#   'Ibiddaa',
#   'Magaalaa',
#   'Adaamaatti',
#   'muudateen',
#   'qabeenyarra',
#   'miidhaan',
#   'ga�e.Balichi',
#   'kan',
#   'muudate',
#   'ganda',
#   '08',
#   'gidduu-gala',
#   'gabaa',
#   'naannoo',
#   'buufta',
#   'konkolaataatti',
#   'yoo',
#   'ta�u',
#   ',',
#   'halkan',
#   'ta�uunsa',
#   'balicha',
#   'hammeessera.Bala',
#   'Ibiddaa',
#   'kanaan',
#   'dukkaanoonni',
#   'meeshaaleen',
#   'gosa',
#   'gara',
#   'garaa',
#   'itti',
#   'gurguraman',
#   '47',
#   'guutummaatti',
#   'gubataniiru.36',
#   'keessammoo',
#   'meeshaan',
#   'hirmaannaa',
#   'hawaasaan',
#   'bararamuu',
#   'Itti',
#   'gaafatamaan',
#   'waajjira',
#   'bulchiinsa',
#   'fi',
#   'nageenyaa',
#   'magaalaa',
#   'Adaamaa',
#   'Obbo',
#   'Zarihuun',
#   'Tafarraa',
#   'himan.maddi',
#   'balaa',
#   'kanaas',
#   'hanga',
#   'yoonaatti',
#   'maal',
#   'akka',
#   'ta�e',
#   'hin',
#   'beekamne.warreen',
#   'balaan',
#   'kun',
#   'isaanirra',
#   'gahes',
#   'qaamni',
#   'dhimmi',
#   'ilaallatu',
#   'akka',
#   'dandamachiisu',
#   'gaafatan',
#   '.'],
#  ['Filiippiinsiitti',
#   'haleellaa',
#   'nama',
#   'eenyumaan',
#   'isaa',
#   'hin',
#   'beekamneen',
#   'hoteelatti',
#   'raawwatameen',
#   'yoo',
#   'xiqqaate',
#   'namoonni',
#   '36',
#   'du�uu',
#   'isaanii',
#   'poolisiin',
#   'biyyattii',
#   'beeksise.Akka',
#   'aangawoonni',
#   'biyyattii',
#   'jedhantti',
#   'namni',
#   'yeroof',
#   'eenyummaan',
#   'isaa',
#   'adda',
#   'hin',
#   'baane',
#   ',',
#   'hoteelaa',
#   'seenuudhaan',
#   'kan',
#   'dhukaasa',
#   'bane.Miidhamtoonni',
#   'haleellichaas',
#   'aara',
#   'meesha',
#   'dhukaafameen',
#   'ukkaamamanii',
#   'kan',
#   'du�an',
#   'ta�uu',
#   'hogganaan',
#   'poolisii',
#   'bulchiinsa',
#   'kibba',
#   'biyyattii',
#   'Toomaas',
#   'Apooliinari�oo',
#   'himan.Aara',
#   'hamaa',
#   'achiitti',
#   'gadi',
#   'lakkifameen',
#   'namni',
#   'naannicha',
#   'gahuuf',
#   'rakkisaa',
#   'akka',
#   'ta�es',
#   'himameNamni',
#   'gocha',
#   'gara',
#   'jabummaa',
#   'raawwate',
#   'kun',
#   'akka',
#   'of',
#   'ajjeese',
#   'Apolinarion',
#   'dubbataniiru.Shakkamtichi',
#   'qaama',
#   'waliin',
#   'yakka',
#   'kana',
#   'raawwate',
#   'akka',
#   'hin',
#   'qabne',
#   'fi',
#   'hoggantichi',
#   'dhimmicha',
#   'ilaalchisee',
#   'poolisiin',
#   'qorachaa',
#   'kan',
#   'jiru',
#   'ta�uu',
#   'dubbatan',
#   '.'],
#  ['Barressaa',
#   'olaanaan',
#   'dhaabbata',
#   'biyyoota',
#   'gamtoomanii',
#   'Antoniyoo',
#   'Guteeres',
#   'balaa',
#   'shoroorkeesitoonni',
#   ',',
#   'Afgaanistaan',
#   'magaala',
#   'Kaabulitti',
#   'qaqabsisan',
#   'dhaabbanni',
#   'isaanii',
#   'akka',
#   'balaleeffatu',
#   'beeksisan.Naannoo',
#   'dipilomaatonni',
#   'biyyoota',
#   'alaa',
#   'hedduun',
#   'argamanitti',
#   'boombii',
#   'konkolaata',
#   'irratti',
#   'kiyyeefameen',
#   'namoonni',
#   '80',
#   'ol',
#   'yoo',
#   'du�an',
#   '350',
#   'ammo',
#   'mada�aniiru.akkaasumaas',
#   'konkolaattonni',
#   '50',
#   'fi',
#   'gamoowwan',
#   'hedduun',
#   'barbada�aniiru.Dubbii',
#   'himaan',
#   'dhaabbata',
#   'biyyoota',
#   'gamtoomanii',
#   'Stefen',
#   'Dujariik',
#   'gocha',
#   'badii',
#   'kana',
#   'ni',
#   'balaaleffana',
#   'ummanni',
#   'addunyaas',
#   'gaheesaa',
#   'gumaachu',
#   'akka',
#   'qabu',
#   'dhaaman.Lammilee',
#   'balaa',
#   'kanaan',
#   'miidhaman',
#   'bayyaanaachisuuf',
#   'mootummaa',
#   'biyyattii',
#   'waliin',
#   'hojjechuuf',
#   'qophii',
#   'ta�uu',
#   'himaniiru',
#   'Rooyitersitu',
#   'gabaase',
#   '.'],
#  ['Hongee',
#   'akka',
#   'dandamannuuf',
#   ',',
#   'deeggarsi',
#   'kennamu',
#   'yeroon',
#   'kan',
#   'nu',
#   'hin',
#   'geenyee',
#   'fi',
#   'gaha',
#   'miti',
#   'jedhan',
#   ',',
#   'Jiraattonni',
#   'Aanaalee',
#   'Areeroo',
#   'fi',
#   'fi',
#   'Liiban.Gaaffii',
#   'hawaasaaf',
#   'furmaata',
#   'kennuuf',
#   'bakka',
#   'rakkoon',
#   'jirutti',
#   'mootummaa',
#   'federaalaa',
#   'waliin',
#   'hojjechaa',
#   'jiraachuu',
#   'komishiniin',
#   'hooggansa',
#   'sodaa',
#   'Balaa',
#   'Oromiyaa',
#   'beeksise',
#   '.'],
#  ['Harri',
#   'Abjaataa',
#   'saffisaan',
#   'hir�ataa',
#   'deemuun',
#   'yaaddoo',
#   'hamaaf',
#   'nu',
#   'saaxile',
#   'jedhan',
#   'jiraattonni',
#   'naannichaa.Warshaan',
#   'waldaa',
#   'aksiyoona',
#   'sodaa',
#   'Ash',
#   ',',
#   'hir�achaa',
#   'deemuu',
#   'harichaaf',
#   'gahee',
#   'olaanaa',
#   'qabaatus',
#   'warshichi',
#   'dhugaa',
#   'kana',
#   'haaluun',
#   ',',
#   'warshaa',
#   'biroo',
#   'naannoo',
#   'hara',
#   'Shaallaatti',
#   'dhaabuuf',
#   'karoorfachuu',
#   'beeksise.Ministeerri',
#   'kunuununsa',
#   'naannoo',
#   ',',
#   'bosonaa',
#   'fi',
#   'jijjiirama',
#   'qilleensaa',
#   'ammoo',
#   'sababni',
#   'guddaan',
#   'hir�achuu',
#   'harichaa',
#   'warshicha',
#   'waan',
#   'ta�eef',
#   'tarkaanfiin',
#   'akka',
#   'fudhatamu',
#   'beeksise',
#   '.'],
#  ['Jiraattootni',
#   'magaalaa',
#   'Mojoo',
#   'ganda',
#   '02',
#   'lolaan',
#   'nu',
#   'dararaa',
#   'waan',
#   'jiruuf',
#   'qaama',
#   'dhimmi',
#   'ilaallatu',
#   'irraa',
#   'furmaata',
#   'barbaanna',
#   'jedhan',
#   '.'],
#  ['Balaa',
#   'tiraafikaa',
#   'daandii',
#   'saffisaa',
#   'Adaamaa-Finfinneerratti',
#   'gaheen',
#   ',',
#   'baatiiwwan',
#   'kurnan',
#   'darban',
#   'keessatti',
#   'qofaa',
#   'lubbuun',
#   'namoota',
#   '17',
#   'darbeera',
#   ',',
#   'namoota',
#   '56rrattis',
#   'midhaa',
#   'cimaan',
#   'qaqqabeera',
#   '.',
#   'Intarpiraayiziin',
#   'daandiwwan',
#   'kaffaltii',
#   'itoophiyaa',
#   'miidhaa',
#   'gahaa',
#   'jiru',
#   'kana',
#   'xiqqeessun',
#   'akkaataa',
#   'danda�amuratti',
#   'qooda',
#   'fudhattootasaa',
#   'waliin',
#   'magaalaa',
#   'bishooftuutti',
#   'mariateera.Hogganaan',
#   'intarpirayizichaa',
#   'obbo',
#   'musxafaa',
#   'kadir',
#   ',',
#   'balaa',
#   'gahaa',
#   'jiru',
#   'xiqqeessuuf',
#   'to�annaa',
#   'teeknolojiidhaan',
#   'deeggarame',
#   'taasisuuf',
#   'akka',
#   'qophaahan',
#   'dubbatan',
#   '.',
#   'Jiraattoti',
#   'naannoos',
#   'dallaa',
#   'daandichaa',
#   'cabsuun',
#   'loonsaanii',
#   'keessa',
#   'galchuunsaanii',
#   'akka',
#   'rakkooti',
#   'ka�eera',
#   '.',
#   'Komishinarri',
#   'komishinii',
#   'poolisii',
#   'oromiyaa',
#   'Ittafaa',
#   'Tolaa',
#   ',',
#   'nageenya',
#   'daandichaa',
#   'eeguuf',
#   ',',
#   'hubannoo',
#   'hawaasaa',
#   'cimsuun',
#   'akka',
#   'barbaachisu',
#   'himan',
#   '.',
#   'Guyyaatti',
#   'konkolaattota',
#   'kuma',
#   '18f',
#   'tajaajila',
#   'kan',
#   'kennaa',
#   'jiru',
#   'daandiin',
#   'kun',
#   ',',
#   'galii',
#   'birii',
#   'miliyoona',
#   'walakaatti',
#   'siiqu',
#   'argamsiisaa',
#   'akka',
#   'jiru',
#   'marii',
#   'qooda',
#   'fudhattoota',
#   'waliin',
#   'taa�ame',
#   'kanaratti',
#   'ibsamee',
#   'jira.Daandiin',
#   'saffisaa',
#   'Finfinnee',
#   'Adaamaa',
#   'battii',
#   'Sadan',
#   'har�aa',
#   'tajaajila',
#   'kennuu',
#   'eegaluunsaa',
#   'beekamaadha',
#   '.'],
#  ['Odeeffannoon',
#   'waa�ee',
#   'haleellaa',
#   'maanchister',
#   ',',
#   'miidiyaa',
#   'Ameerkaatiin',
#   'dursee',
#   'gadi',
#   'dhiifame',
#   ',',
#   'Amantaan',
#   'Pirezidaant',
#   'Traampiif',
#   'qabu',
#   'na',
#   'shakkisiiseera',
#   'jedhan',
#   'Ministirri',
#   'muummee',
#   'Biriiteen',
#   'Teresaa',
#   'Meey.Aanga�oonni',
#   'gameeyyiin',
#   'Biriiteen',
#   'wayita',
#   'caccabaa',
#   'meeshaa',
#   'waraanaa',
#   'lammiileen',
#   'maanchester',
#   'ittiin',
#   'haleelaman',
#   'barruu',
#   'beekamaa',
#   'Ameerkaa',
#   'NewYork',
#   'times',
#   'irratti',
#   'argatan',
#   'aariidhaan',
#   'of',
#   'nyaatan.Kanarraa',
#   'kan',
#   'hubannu',
#   'odeeffannoon',
#   'haleellaa',
#   'maanchister',
#   'dursitee',
#   'lootee',
#   'warra',
#   'Ameerkaa',
#   'bira',
#   'ga�uusheeti',
#   'jedhan',
#   'Ministirri',
#   'Muummee',
#   'Teresaa',
#   'Meey.Teresaa',
#   'Meey',
#   'Yaa�ii',
#   'NATO',
#   'taa�amuuf',
#   'jedhurratti',
#   'dhimma',
#   'kana',
#   'pirezidaanti',
#   'Tiraampiif',
#   'kaasuuf',
#   'qophaa�aniiru.Haleellaa',
#   'lammiilee',
#   '22',
#   'ajjeesee',
#   '64',
#   'madeesse',
#   'kanaaf',
#   'kan',
#   'shakkame',
#   'Salman',
#   'Abadi',
#   'eenyummaansaa',
#   'yeroo',
#   'gabaabaa',
#   'balichi',
#   'mudate',
#   'sa�atii',
#   '24',
#   'keessatti',
#   'kan',
#   'ibse',
#   'miidiyaa',
#   'Ameerikaati',
#   'jedha',
#   'gabaasni',
#   'BBC',
#   '.'],
#  ['Hojjattoonni',
#   'fi',
#   'barattonii',
#   'yuunivarsitii',
#   'Bulee',
#   'Horaa',
#   ',',
#   'jiraattota',
#   'godinaalee',
#   'Booranaa',
#   'fi',
#   'Gujii',
#   'hoongeen',
#   'miidhamanif',
#   'birrii',
#   'miiliyoona',
#   'lama',
#   'caalu',
#   'deeggaran.Hojjattonni',
#   'yuunivarsitichaa',
#   'mindaa',
#   'ji�aa',
#   'irraa',
#   'harka',
#   'digdama',
#   ',',
#   'baratoonni',
#   'ammoo',
#   'nyaata',
#   'isaanii',
#   'irbaata',
#   'guyyaa',
#   'lamaa',
#   'walumatti',
#   ',',
#   'birrii',
#   'miiliyoona',
#   'lamaa',
#   'fi',
#   'kuma',
#   'dhibba',
#   'shanitti',
#   'siqu',
#   'deeggaraniiru.Pireezidaantiin',
#   'Yuunivarsiittii',
#   'Bulee',
#   'Horaa',
#   'Doktar',
#   'Abdulqaadir',
#   'Huseen',
#   ',',
#   'hawaasa',
#   'keenya',
#   'tajaajiluun',
#   'akkuma',
#   'dirqama',
#   'keenya',
#   'ta�e',
#   ',',
#   'rakkoo',
#   'hoongee',
#   'muudate',
#   'kanarratti',
#   'cinaa',
#   'isaa',
#   'dhabbachuunis',
#   'ga�ee',
#   'keenya',
#   'bahachaarra',
#   'jedhan.Guyyoo',
#   'Jilootu',
#   'gabaase'],
#  ['Godina',
#   'Baalee',
#   'Aanaa',
#   'Gindhiiritti',
#   ',',
#   'roobni',
#   'cimaan',
#   'tibbana',
#   'roobee',
#   'qabeenya',
#   'birri',
#   'miliyoona',
#   '17tti',
#   'tilmaamamu',
#   'mancaase.Waajjirri',
#   'Hooggansa',
#   'Sodaa',
#   'Balaa',
#   'aanichaa',
#   'gamasaatiin',
#   ',',
#   'qonnaan',
#   'bultoota',
#   'miidhaman',
#   'bayyanachiisuuf',
#   'koree',
#   'hundeessee',
#   'hojjataa',
#   'akka',
#   'jiru',
#   'beksiseera',
#   '.'],
#  ['Dooniin',
#   'Godaantoota',
#   'lammiilee',
#   'Moorokoo',
#   'baattee',
#   'Awurooppaa',
#   'galuuf',
#   'galaana',
#   'irra',
#   'imalaa',
#   'turte',
#   'tasa',
#   'ibiddi',
#   'itti',
#   'qabatee',
#   'gubatte',
#   '.',
#   'Dooniin',
#   'godaantota',
#   'Moorokoo',
#   '34',
#   'baachuudhan',
#   'imalaa',
#   'turte',
#   'kun',
#   'qarqara',
#   'galaana',
#   'daangaa',
#   'Ispeen',
#   'yeroo',
#   'geessetti',
#   'ibiddi',
#   'itti',
#   'qabachuu',
#   'isheetiin',
#   'humni',
#   'qilleensaa',
#   'Poorchugaal',
#   'lubbuu',
#   'isaanii',
#   'baraaruu',
#   'akka',
#   'danda�e',
#   'himame.Sababni',
#   'balaa',
#   'kanaa',
#   'beekamuu',
#   'baatus',
#   ',',
#   'laboobni',
#   'ibiddaa',
#   'gama',
#   'motora',
#   'doonii',
#   'irraa',
#   'ka�ee',
#   'fi',
#   'namootni',
#   'doonii',
#   'keessa',
#   'turan',
#   'yommuu',
#   'gara',
#   'galaanaatti',
#   'utaalan',
#   'viidiyoon',
#   'agarsiisu',
#   'gadi',
#   'lakkifamee',
#   'jira.Humni',
#   'qilleensa',
#   'Poorchugaal',
#   'ariitiin',
#   'dhaqqabuu',
#   'isaatiin',
#   'lubbuun',
#   'godaantota',
#   'doonii',
#   'kessa',
#   'turanii',
#   'baraaramuu',
#   '.',
#   'Rooytarsi',
#   'gabaasee',
#   'jira',
#   '.'],
#  ['Balaa',
#   'lolaa',
#   'fi',
#   'sigiga',
#   'lafaa',
#   'siriilaankatti',
#   'uumameen',
#   'namoonni',
#   '117',
#   'lubbuun',
#   'isaanii',
#   'yoo',
#   'darbu',
#   '109',
#   'ammoo',
#   'as-buuteen',
#   'isaanii',
#   'dhabame.Ragaan',
#   'giddugala',
#   'ittisa',
#   'balaa',
#   'Siriilaankaa',
#   'irraa',
#   'argame',
#   'akka',
#   'agarsiisutti',
#   ',',
#   'namootni',
#   '117',
#   'lubbuun',
#   'isaanii',
#   'darbuufi',
#   'lakkoofsi',
#   'namoota',
#   'du�anii',
#   'akka',
#   'dabaluu',
#   'danda�u',
#   'ibsamee',
#   'jira.Hojiin',
#   'lubbu',
#   'baraaruu',
#   'cimee',
#   'hojjetamaa',
#   'akka',
#   'jirus',
#   'mootummaan',
#   'biyyattii',
#   'beeksiseera.Dhaabbanni',
#   'meetiyooroloojii',
#   'biyyattiis',
#   'taatee',
#   'haalaa',
#   'qilleensaa',
#   'guyyaa',
#   'guyyaan',
#   'uumamu',
#   'dursee',
#   'kan',
#   'akeekkachiisaa',
#   'jiru',
#   'ta�us',
#   'roobni',
#   'cimaan',
#   'roobaa',
#   'jiru',
#   'balaan',
#   'uumame',
#   'akka',
#   'cimu',
#   'taasisee',
#   'jira.Kunis',
#   'lammiileen',
#   'biyyattii',
#   'kuma',
#   'dhibba',
#   'shan',
#   'ta�an',
#   'iddoo',
#   'jireenya',
#   'isaaniitii',
#   'akka',
#   'buqqa�anii',
#   'fi',
#   'manneen',
#   'Kuma',
#   'Afurtamii',
#   'Sadeet',
#   ',',
#   'akka',
#   'diigamaniif',
#   'sababa',
#   'ta�ee',
#   'jira',
#   'akka',
#   'ragaan',
#   'giddu',
#   'gala',
#   'ittisa',
#   'balaa',
#   'biyyattii',
#   'iraa',
#   'argame',
#   'agarsiisutti',
#   '.'],
#  ...]

# %%
model=word2vec(newsvec,min_count=1,size=32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a0806b4a2632> in <module>()
# ----> 1 model=word2vec(newsvec,min_count=1,size=32)
#
# NameError: name 'word2vec' is not defined

# %%
model.most_similar('nama')

# %%
import  gensim
from gensim import models
from gensim.models import word2vec

# %%
EMBEDDING_DIM=300
model = models.gensim.word2vec(sentences=newsContents,size=EMBEDDING_DIM,window=10,min_count=2,workers=4,sg=0)
words=list(model.wv.vocab)
